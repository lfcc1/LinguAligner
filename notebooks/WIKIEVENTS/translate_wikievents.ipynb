# %%
import json
file_dev = open("../../Datasets/WikiEvents/dev.jsonl")
file_train = open("../../Datasets/WikiEvents/train.jsonl")
file_test = open("../../Datasets/WikiEvents/test.jsonl")
docs_dev = []
docs_train = []
docs_test = []
for line in file_dev:
    docs_dev.append(json.loads(line))
    
for line in file_train:
    docs_train.append(json.loads(line))

for line in file_test:
    docs_test.append(json.loads(line))
    
file_train.close()
file_dev.close()
file_test.close()

# %%
from LinguAligner import AlignmentPipeline, translation
translator = translation.GoogleTranslator(source_lang="en", target_lang="pt")
aligner = AlignmentPipeline()
# Out:
# Loading spacy model: pt_core_news_lg
# Model loaded
# Loading WAligner model: bert-base-multilingual-uncased
# Model loaded

# %% [markdown]
# ### Generate multi-translation Lookuptable

# %%
entities = set()
triggers = set()
for doc in docs_dev:
    for entity in doc["entity_mentions"]:
        entities.add(entity["text"])
    for event in doc["event_mentions"]:
        triggers.add(event["trigger"]["text"])
for doc in docs_train:
    for entity in doc["entity_mentions"]:
        entities.add(entity["text"])
    for event in doc["event_mentions"]:
        triggers.add(event["trigger"]["text"])
for doc in docs_test:
    for entity in doc["entity_mentions"]:
        entities.add(entity["text"])
    for event in doc["event_mentions"]:
        triggers.add(event["trigger"]["text"])
triggers = list(triggers)
entities = list(entities)

# %%
lookupTable = {}

# %%
translator = translation.MicrosoftTranslator(source_lang="en", target_lang="pt", auth_key="f6d44239a73046ca8378bcdc689b395c")
annotations_list = triggers
for word in annotations_list:
    if word not in lookupTable and len(word) < 50:
        print(word)
        lookupTable[word] = translator.getMultipleTranslations(word) # change the language codes according to the desired languages
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 translator = translation.MicrosoftTranslator(source_lang="en", target_lang="pt", auth_key="f6d44239a73046ca8378bcdc689b395c")
# ----> 2 annotations_list = triggers
#       3 for word in annotations_list:
#       4     if word not in lookupTable and len(word) < 50:
#
# NameError: name 'triggers' is not defined

# %%
#f_out = open("lookupTable_triggers.json", "w")
#json.dump(lookupTable, f_out, indent=4, ensure_ascii=False)

# %% [markdown]
# ### Translate and align annotations on the sentence level
# (aligning annotations on sentence level is easier)

# %%
import json
lookupTable_triggers = json.load(open("lookupTable_triggers.json"))
lookupTable_entities = json.load(open("lookupTable_entities.json"))

# %%
def token_index_doc_to_sent(sentences, sent_idx, ann_index):
    i = 0
    token_offset = 0
    while i < sent_idx:
        token_offset += len(sentences[i][0])
        i = i + 1
    return ann_index - token_offset

#print(token_index_doc_to_sent(docs_dev[0]["sentences"],2, 58))

def token_to_char_offset(tokens, index):
    start, end = 0, 0
    for token in tokens[:index]:
        start = start + len(token) + 1
    #print(tokens[index])
    end = start + len(tokens[index])
    return start, end

#token_to_char_offset(docs_dev[0]["tokens"],58)

# %%
import spacy

nlp = spacy.load("pt_core_news_lg")

# %%
def getEntityText(id, entities):
    for entity in entities:
        if entity["id"] == id:
            return entity["text"]
    return None


def align_annotations(sentences_src, sentences_trans, sent_idx, ann_src , ann_src_start, translated_ann,lookupTable):
    sent_tokens, sent_text = sentences_src[sent_idx]
    print(sentences_src[sent_idx][1], sentences_trans[sent_idx], ann_src , translated_ann, sep="\n")
    ann_token_index = token_index_doc_to_sent(sentences_src, sent_idx, ann_src_start)
    src_ann_start, scr_ann_end = token_to_char_offset(sent_tokens, ann_token_index)
    print(sent_text, ann_src, sentences_trans[sent_idx], translated_ann, sep="\n")
    target_annotation = aligner.align_annotation(sent_text, ann_src, sentences_trans[sent_idx], translated_ann, lookupTable=lookupTable, src_ann_start=src_ann_start)
    print(target_annotation, ann_src, src_ann_start, scr_ann_end)
    return target_annotation

def translate_docs(docs):
    new_docs = []
    for doc in docs:
        trans_sencences = []
        new_doc = {}
        new_doc["event_mentions"] = []
        new_doc["entity_mentions"] = []
        new_doc["relation_mentions"] = doc["relation_mentions"]
        
        #Translate sentences
        for sent in doc["sentences"]:
            sent[1] = sent[1].replace("","")
            if len(sent[1]) > 5000:
                doc_ = nlp(sent[1])
                trans_sent = ""
                for sent_ in doc_.sents:
                    trans_sent = trans_sent + " " + translator.translate(sent_.text)
                trans_sent = trans_sent.strip()
            else:        
                trans_sent = translator.translate(sent[1])
            trans_sencences.append(trans_sent)
        
        #Translate and align entities
        for ann in doc["entity_mentions"]:
            ann["text"] = ann["text"].replace("","")
            translated_ann = translator.translate(ann["text"])
            aligned_ann, span = align_annotations(doc["sentences"], 
                                            trans_sencences, 
                                            ann["sent_idx"],  
                                            ann["text"], 
                                            ann["start"], 
                                            translated_ann, 
                                            lookupTable_entities)
            ann["text_en"]= ann["text"]
            ann["text"] = aligned_ann
            ann["start_en"] = ann["start"]
            ann["end_en"] = ann["end"]
            ann["start"] = span[0]
            ann["end"] = span[1]
            new_doc["entity_mentions"].append(ann)
        
        #Translate and align events
        for ann in doc["event_mentions"]:
            ann["trigger"]["text"] = ann["trigger"]["text"].replace("","")
            translated_ann = translator.translate(ann["trigger"]["text"]).replace("","")
            aligned_ann, span = align_annotations(doc["sentences"], 
                                                trans_sencences, 
                                                ann["trigger"]["sent_idx"],  
                                                ann["trigger"]["text"], 
                                                ann["trigger"]["start"],
                                                translated_ann,
                                                lookupTable_triggers)
            ann["trigger"]["text_en"]= ann["trigger"]["text"]
            ann["trigger"]["text"] = aligned_ann 
            ann["trigger"]["start_en"] = ann["trigger"]["start"]
            ann["trigger"]["end_en"] = ann["trigger"]["end"]
            ann["trigger"]["start"] = span[0]
            ann["trigger"]["end"] = span[1]
            #arguments
            for arg in ann["arguments"]:
                text = getEntityText(arg["entity_id"], new_doc["entity_mentions"])
                arg["text_en"] = arg["text"]
                arg["text"] = text
            new_doc["event_mentions"].append(ann)


        new_doc["sentences_en"] = [sent for _, sent in doc["sentences"]]
        new_doc["sentences"] = trans_sencences
        new_doc["text_en"] = doc["text"]
        new_doc["text"] = " ".join(trans_sencences)
        new_docs.append(new_doc)
    return new_docs
    
def saveJsonLines(docs, filename):
    with open(filename, 'w') as outfile:
        for entry in docs:
            json.dump(entry, outfile)
            outfile.write('\n')
        outfile.flush()

# %%
docs_dev_pt = translate_docs(docs_dev)
saveJsonLines(docs_dev_pt, "../../Datasets/WikiEvents/dev_pt_sent.jsonl")
f_out = open("../../Datasets/WikiEvents/dev_pt_sent.json", "w")
json.dump(docs_dev_pt, f_out, indent=4, ensure_ascii=False)
f_out.flush()
f_out.close()

docs_train_pt = translate_docs(docs_train)
saveJsonLines(docs_train_pt, "../../Datasets/WikiEvents/train_pt_sent.jsonl")
f_out = open("../../Datasets/WikiEvents/train_pt_sent.json", "w")
json.dump(docs_train_pt, f_out, indent=4, ensure_ascii=False)
f_out.flush()
f_out.close()

docs_test_pt = translate_docs(docs_test)
saveJsonLines(docs_test_pt, "../../Datasets/WikiEvents/test_pt_sent.jsonl")
f_out = open("../../Datasets/WikiEvents/test_pt_sent.json", "w")
json.dump(docs_test_pt, f_out, indent=4, ensure_ascii=False)
f_out.flush()
f_out.close()
# Out:
# ('IED', (0, 2)) IED 4 7
# ('russo', (42, 46)) Russian 12 15
# ('major-general', (28, 40)) general 20 23
# ('Síria', (51, 55)) Syria 28 31
# ('deserto', (2, 8)) desert 4 7
# ('Deir ez-Zor', (29, 39)) Deir ez-Zor 24 27
# ('regime', (53, 58)) regime 48 51
# ('Eufrates', (63, 70)) Euphrates 72 75
# ('insurgentes', (89, 99)) insurgents 88 91
# ('Rússia', (14, 19)) Russia 0 3
# ('Síria', (24, 28)) Syria 20 23
# ('país', (109, 112)) nation 64 67
# ('Ministério da Defesa', (80, 99)) Defense Ministry 76 79
# ('major-general', (131, 143)) general 100 103
# ('Síria', (158, 162)) Syria 116 119
# ('dispositivo explosivo', (171, 191)) explosive device 132 135
# ('Al-Monitor', (217, 226)) Al-Monitor 144 147
# ('major-general', (2, 14)) General 4 7
# ('Vyacheslav Gladkikh', (16, 34)) Vyacheslav Gladkikh 8 11
# ('IED', (57, 59)) IED 32 35
# ('comboio', (92, 98)) convoy 48 51
# ('russos', (112, 117)) Russian 56 59
# ('soldados', (103, 110)) soldiers 60 63
# ('sírios', (143, 148)) Syrian 68 71
# ('regime', (136, 141)) regime 80 83
# ('milicianos', (121, 130)) militiamen 84 87
# ('cidade', (159, 164)) city 96 99
# ('Deir ez-Zor', (169, 179)) Deir ez-Zor 104 107
# ('russos', (22, 27)) Russian 8 11
# ('militares', (12, 20)) military 12 15
# ('militares', (12, 20)) personnel 16 19
# ('russa', (85, 89)) Russia 32 35
# ('estatal', (77, 83)) state 44 47
# ('Tass', (91, 94)) Tass 56 59
# ('agência', (57, 63)) agency 64 67
# ('comandante', (3, 12)) commander 8 11
# ('Síria', (53, 57)) Syria 16 19
# ('Forças de Defesa Nacional', (24, 48)) National Defense Forces 28 31
# ('Assad', (76, 80)) Assad 56 59
# ('milícia', (64, 70)) militia 60 63
# ('Eles', (1, 4)) They 4 7
# ('Eles', (1, 4)) their 20 23
# ('lá', (24, 25)) there 28 31
# ('fonte', (39, 43)) source 48 51
# ('que', (46, 48)) who 56 59
# ('Eles', (1, 4)) They 4 7
# ('minas', (43, 47)) mines 28 31
# ('russo', (44, 48)) Russian 32 35
# ('general', (36, 42)) general 36 39
# ('Síria', (53, 57)) Syria 44 47
# ('general', (89, 95)) general 72 75
# ('província', (116, 124)) province 96 99
# ('morteiro', (153, 160)) mortar 112 115
# ('Estado Islâmico', (165, 179)) Islamic State 128 131
# ('Al-Monitor', (193, 202)) Al-Monitor 140 143
# ('Deir ez-Zor', (0, 10)) Deir ez-Zor 0 3
# ('sírio', (38, 42)) Syrian 32 35
# ('território', (27, 36)) territory 36 39
# ('rio Eufrates', (55, 66)) Euphrates River 52 55
# ('sírio', (94, 98)) Syrian 68 71
# ('governo', (86, 92)) government 72 75
# ('província de Idlib', (129, 146)) Idlib province 104 107
# ('rebelde', (166, 172)) rebel 124 127
# ('enclave', (158, 164)) enclave 128 131
# ('país', (193, 196)) country 140 143
# ('no', (180, 181)) US 0 3
# ('curdos', (46, 51)) Kurdish 16 19
# ('Milícias', (0, 7)) militias 28 31
# ('está', (211, 214)) IS 36 39
# ('território', (73, 82)) territory 52 55
# ('desértica', (138, 146)) desert 80 83
# ('zona rural', (127, 136)) countryside 84 87
# ('Deir ez-Zor', (167, 177)) Deir ez-Zor 104 107
# ('regime', (191, 196)) regime 128 131
# ('Eufrates', (201, 208)) Euphrates 152 155
# ('insurgentes', (227, 237)) insurgents 168 171
# ('que', (239, 241)) who 172 175
# (None, (-1, -1)) Syrian 196 199
# ('regime', (191, 196)) regime 200 203
# ('forças', (264, 269)) forces 204 207
# ('Al-Monitor', (303, 312)) Al-Monitor 212 215
# ('Síria', (33, 37)) Syria 0 3
# ('Badia', (11, 15)) Badia 16 19
# ('deserto', (21, 27)) desert 28 31
# ('país', (114, 117)) country 44 47
# ('ponto', (64, 68)) spot 68 71
# ('ser', (51, 53)) IS 76 79
# ('sírios', (46, 51)) Syrian 28 31
# ('regime', (57, 62)) regime 40 43
# ('combatentes', (34, 44)) fighters 44 47
# ('foram', (64, 68)) IS 60 63
# ('Badia al-Sukhnah', (97, 112)) Badia al-Sukhnah 72 75
# ('Badia al-Sham', (116, 128)) Badia al-Sham 92 95
# ('russos', (157, 162)) Russian 116 119
# ('Observatório Sírio para os Direitos Humanos', (181, 223)) Syrian Observatory for Human Rights 140 143
# ('figuras', (19, 25)) figures 16 19
# ('lado', (66, 69)) side 36 39
# ('Eufrates', (80, 87)) Euphrates 48 51
# ('Deir ez-Zor', (92, 102)) Deir ez-Zor 56 59
# ('que', (105, 107)) which 76 79
# ('curdos', (171, 176)) Kurdish 96 99
# ('Forças Democráticas Sírias', (128, 153)) Syrian Democratic Forces 108 111
# ('Al-Monitor', (190, 199)) Al-Monitor 124 127
# ('quem', (15, 18)) who 16 19
# ('moradores locais', (56, 71)) locals 44 47
# ('está', (4, 7)) IS 60 63
# ('Assad', (124, 128)) Assad 72 75
# ('regime', (114, 119)) regime 76 79
# ('no', (43, 44)) US 4 7
# ('autoridade', (4, 13)) official 8 11
# ('Al-Monitor', (32, 41)) Al-Monitor 16 19
# ('insurgentes', (97, 107)) IS 88 91
# ('insurgentes', (97, 107)) insurgents 92 95
# ('células', (118, 124)) cells 104 107
# ('Iraque', (141, 146)) Iraq 112 115
# ('Síria', (153, 157)) Syria 120 123
# ('coligação', (15, 23)) Coalition 0 3
# ('porta-voz', (2, 10)) spokesman 4 7
# ('no', (156, 157)) US 8 11
# ('Exército', (37, 44)) Army 12 15
# ('coronel', (26, 32)) Col 16 19
# ('Myles Caggins III', (55, 71)) Myles Caggins III 24 27
# ('Al-Monitor', (83, 92)) Al-Monitor 40 43
# ('no', (156, 157)) US 60 63
# ('iraquianas', (144, 153)) Iraqi 72 75
# ('autoridades', (132, 142)) authorities 76 79
# ('fronteiriça', (228, 238)) border 116 119
# ('fronteiriça', (228, 238)) border 152 155
# ('área', (281, 284)) area 156 159
# ('Pentágono', (2, 10)) Pentagon 4 7
# ('na', (51, 52)) US 12 15
# ('forças', (26, 31)) forces 20 23
# ('al-Tanf', (70, 76)) al-Tanf 36 39
# ('base', (54, 57)) base 48 51
# ('Badia', (81, 85)) Badia 60 63
# ('lá', (93, 94)) there 68 71
# ('estão', (87, 91)) IS 88 91
# ('fronteiriça', (137, 147)) border 100 103
# ('área', (132, 135)) area 104 107
# ('rebeldes', (157, 164)) rebels 116 119
# ('Al-Monitor', (178, 187)) Al-Monitor 128 131
# ('russas', (218, 223)) Russian 156 159
# ('sírias', (227, 232)) Syrian 164 167
# ('forças', (211, 216)) forces 168 171
# ('estradas', (238, 245)) roads 180 183
# ('na', (234, 235)) US 192 195
# ('zona', (261, 264)) zone 204 207
# ('área', (309, 312)) area 224 227
# ('mata', (23, 26)) kills 8 11
# ('morto', (149, 153)) killed 108 111
# ('informou', (206, 213)) reported 160 163
# ('morreu', (36, 41)) died 16 19
# ('feridos', (37, 43)) wounded 24 27
# ('morto', (101, 105)) killed 80 83
# ('morto', (101, 105)) killed 80 83
# ('relatada', (21, 28)) reported 152 155
# ('mortos', (70, 75)) killed 52 55
# ('informou', (179, 186)) reported 136 139
# ('relatou', (293, 299)) reported 224 227
# ('ataques', (80, 86)) attacks 64 67
# ('contrabando', (258, 268)) smuggling 140 143
# ('confirmou', (114, 122)) confirmed 84 87
# ('informou', (46, 53)) reported 68 71
# ('disse', (29, 33)) said 40 43
# ('foguete', (61, 67)) rocket 40 43
# ('Câmara', (586, 591)) house 400 403
# ('Freddy Guevara', (17, 30)) Freddy Guevara 16 19
# ('lhes', (241, 244)) them 176 179
# ('eles', (58, 61)) them 40 43
# ('eles', (135, 138)) them 128 131
# ('lhes', (149, 152)) them 132 135
# ('lhes', (149, 152)) them 148 151
# ('alimentá-las', (83, 94)) them 60 63
# ('são', (400, 402)) s 156 159
# ('foram', (171, 175)) s 264 267
# (None, (-1, -1)) s 64 67
# ('foram', (36, 40)) s 128 131
# ('foram', (36, 40)) s 8 11
# (None, (-1, -1)) s 20 23
# (None, (-1, -1)) s 8 11
# (None, (-1, -1)) s 8 11
# ('nos', (151, 153)) we 164 167
# ('tivéssemos', (50, 59)) we 60 63
# ('Teremos', (160, 166)) We 112 115
# ('eles', (49, 52)) we 96 99
# ('ela', (253, 255)) her 84 87
# ('ela', (253, 255)) her 116 119
# ('lhe', (143, 145)) her 152 155
# ('dela', (281, 284)) her 60 63
# ('dela', (281, 284)) her 232 235
# ('dela', (281, 284)) her 240 243
# ('Seu', (0, 2)) Her 0 3
# ('lhe', (143, 145)) her 192 195
# ('estado', (172, 177)) state 132 135
# ('estão', (82, 86)) state 44 47
# ('está', (32, 35)) state 140 143
# ('estado', (59, 64)) state 44 47
# ('estado', (26, 31)) state 24 27
# ('empresa', (40, 46)) company 52 55
# ('administração', (356, 368)) administration 232 235
# ('administração', (3, 15)) administration 8 11
# ('Leopoldo López', (549, 562)) Leopoldo López 340 343
# ('Nicolás Maduro', (112, 125)) Nicolás Maduro 88 91
# ('Hugo Chávez', (48, 58)) Hugo Chávez 32 35
# ('que', (61, 63)) who 44 47
# ('Maduro', (0, 5)) Maduro 0 3
# ('Maduro', (435, 440)) Maduro 284 287
# ('Maduro', (25, 30)) Maduro 0 3
# ('Maduro', (320, 325)) Maduro 204 207
# ('Maduro', (0, 5)) Maduro 0 3
# ('Maduro', (183, 188)) Maduro 144 147
# ('Maduro', (108, 113)) Maduro 96 99
# ('Maduro', (86, 91)) Maduro 52 55
# ('Maduro', (0, 5)) Maduro 0 3
# ('Ele', (370, 372)) him 320 323
# ('Ela', (191, 193)) She 152 155
# (None, (-1, -1)) s 8 11
# ('líderes da oposição', (435, 453)) opposition leaders 268 271
# ('retirar', (283, 289)) strip 176 179
# ('instituições', (202, 213)) institutions 144 147
# ('embaixada', (325, 333)) embassy 232 235
# ('tribunal', (235, 242)) court 156 159
# ('tribunal', (29, 36)) court 148 151
# ('este', (266, 269)) it 164 167
# ('país', (174, 177)) country 120 123
# ('país', (465, 468)) country 292 295
# ('país', (4, 7)) country 8 11
# ('país', (10, 13)) country 12 15
# ('país', (202, 205)) country 120 123
# ('país', (375, 378)) country 232 235
# ('onde', (470, 473)) where 296 299
# ('onde', (9, 12)) where 12 15
# ('Manifestantes', (67, 79)) Protesters 40 43
# ('manifestantes', (251, 263)) protesters 164 167
# ('manifestantes', (106, 118)) protesters 120 123
# ('escola', (134, 139)) school 96 99
# ('o sistema judicial militar', (177, 202)) the military 140 143
# ('militar', (38, 44)) military 32 35
# ('militar', (180, 186)) military 100 103
# ('prisão', (384, 389)) jail 388 391
# ('prisão', (384, 389)) jail 232 235
# ('prisão', (219, 224)) jail 200 203
# ('conselho', (180, 187)) council 136 139
# ('conselho', (180, 187)) council 240 243
# ('José', (198, 201)) José 132 135
# ('me', (102, 103)) me 124 127
# ('me', (186, 187)) me 224 227
# ('forças de segurança', (108, 126)) security forces 56 59
# ('China', (317, 321)) China 192 195
# ('me', (68, 69)) I 4 7
# ('me', (102, 103)) I 88 91
# ('me', (186, 187)) I 160 163
# ('me', (186, 187)) I 180 183
# ('me', (186, 187)) I 204 207
# ('Não', (1, 3)) I 4 7
# ('Não', (1, 3)) I 28 31
# ('Não', (231, 233)) I 216 219
# ('Não', (231, 233)) I 168 171
# ('Tenho', (28, 32)) I 44 47
# ('sua', (617, 619)) his 384 387
# ('seu', (96, 98)) his 84 87
# ('seu', (122, 124)) his 80 83
# ('o governo', (91, 99)) the government 56 59
# ('o governo', (506, 514)) the government 312 315
# ('do governo', (367, 376)) the government 216 219
# ('do governo', (132, 141)) the government 96 99
# ('o governo', (14, 22)) the government 16 19
# ('do governo', (83, 92)) the government 40 43
# ('do governo', (143, 152)) the government 80 83
# ('o governo', (22, 30)) the government 16 19
# ('o governo', (52, 60)) the government 40 43
# ('o governo', (111, 119)) the government 72 75
# ('o governo', (265, 273)) the government 152 155
# ('o governo', (289, 297)) the government 204 207
# ('a região', (142, 149)) the region 96 99
# ('centros', (173, 179)) centers 128 131
# ('negócio', (280, 286)) business 188 191
# ('bens', (59, 62)) assets 72 75
# ('regime', (171, 176)) regime 140 143
# ('governo', (215, 221)) government 156 159
# ('governo', (17, 23)) Government 0 3
# ('governo', (508, 514)) Government 136 139
# ('governo', (400, 406)) government 244 247
# ('governo', (157, 163)) government 104 107
# ('governo', (408, 414)) government 236 239
# ('governo', (413, 419)) government 300 303
# ('governo', (413, 419)) government 356 359
# ('governo', (157, 163)) government 44 47
# ('governo', (248, 254)) government 148 151
# (None, (-1, -1)) government 116 119
# (None, (-1, -1)) government 116 119
# ('governo', (267, 273)) government 128 131
# ('palácio', (170, 176)) palace 140 143
# ('o Mar', (254, 258)) the Caribbean Sea 180 183
# ('Trump', (370, 374)) Trump 228 231
# ('Trump', (17, 21)) Trump 4 7
# ('espanhol', (196, 203)) Spanish 132 135
# ('legislatura', (374, 384)) legislature 268 271
# ('legislatura', (301, 311)) legislature 204 207
# ('pátria', (58, 63)) homeland 52 55
# ('da Assembleia Nacional', (69, 90)) the National Assembly 56 59
# ('venezuelanos', (33, 44)) Venezuelans 20 23
# ('venezuelanos', (19, 30)) Venezuelans 8 11
# ('Rússia', (305, 310)) Russia 184 187
# ('Henrique Capriles', (17, 33)) Henrique Capriles 20 23
# ('armas', (232, 236)) guns 152 155
# ('Ueslei Marcelino', (464, 479)) Ueslei Marcelino 288 291
# ('Somália', (1, 7)) Somalia 4 7
# ('congresso', (109, 117)) congress 76 79
# ('congresso', (27, 35)) congress 28 31
# ('ditadura', (34, 41)) dictatorship 28 31
# ('ditadura', (159, 166)) dictatorship 100 103
# ('ditadura', (149, 156)) dictatorship 100 103
# ('ônibus', (217, 222)) bus 148 151
# ('prisão', (242, 247)) prison 180 183
# ('negócio', (280, 286)) businesses 152 155
# ('Tareck El Aissami', (94, 110)) Tareck El Aissami 48 51
# ('Assembleia', (326, 335)) Constituent Assembly 204 207
# ('assembleia', (111, 120)) assembly 80 83
# ('assembleia', (281, 290)) assembly 200 203
# ('assembleia', (28, 37)) assembly 20 23
# ('assembleia', (62, 71)) assembly 48 51
# ('assembleia', (457, 466)) assembly 332 335
# ('assembleia', (36, 45)) assembly 24 27
# ('Miranda', (80, 86)) Miranda 68 71
# ('estado', (70, 75)) state 60 63
# ('nos', (12, 14)) We 4 7
# ('empregador', (34, 43)) employer 36 39
# ('Mariana Zuñiga', (0, 13)) Mariana Zuñiga 0 3
# ('Washington Post World', (8, 28)) Washington Post World 4 7
# ('pela oposição', (397, 409)) the opposition 252 255
# ('pela oposição', (322, 334)) the opposition 188 191
# ('a oposição', (222, 231)) the opposition 148 151
# ('que', (268, 270)) it 160 163
# ('ele', (152, 154)) him 116 119
# ('Post', (41, 44)) Post 20 23
# ('Guevara', (313, 319)) Guevara 224 227
# ('Ramírez', (0, 6)) Ramírez 0 3
# ('que', (9, 11)) who 8 11
# ('ela', (204, 206)) she 152 155
# ('Luis González Añez', (100, 117)) Luis González Añez 100 103
# ('lhe', (143, 145)) her 88 91
# ('que', (129, 131)) who 124 127
# ('José Luis Rodríguez Zapatero', (205, 232)) José Luis Rodríguez Zapatero 144 147
# ('Gabriela Ramírez', (0, 15)) Gabriela Ramírez 0 3
# ('Yanelis Banco', (37, 49)) Yanelis Banco 32 35
# ('Lisbeth Añez', (22, 33)) Lisbeth Añez 40 43
# ('Departamento do Tesouro dos EUA', (2, 32)) U.S. Treasury Department 4 7
# ('Caracas', (596, 602)) Caracas 368 371
# ('Caracas', (338, 344)) Caracas 240 243
# ('Caracas', (227, 233)) Caracas 144 147
# ('Caracas', (455, 461)) Caracas 280 283
# ('Caracas', (242, 248)) Caracas 168 171
# ('Departamento de Estado dos EUA', (230, 259)) U.S. State Department 164 167
# ('à Cordilheira dos Andes', (277, 299)) the Andes Mountains 196 199
# ('sul-americano', (179, 191)) South American 112 115
# ('América do Sul', (39, 52)) South America 28 31
# ('americanos', (307, 316)) American 216 219
# ('americanos', (307, 316)) American 272 275
# ('americanos', (64, 73)) American 68 71
# ('dos EUA', (253, 259)) U.S. 312 315
# ('nos', (12, 14)) us 20 23
# ('nos', (151, 153)) us 144 147
# ('bandeira', (430, 437)) flag 268 271
# ('América Latina', (69, 82)) Latin America 48 51
# ('Chávez', (247, 252)) Chávez 156 159
# ('Chávez', (69, 74)) Chávez 36 39
# ('Chávez', (151, 156)) Chávez 116 119
# ('Chávez', (87, 92)) Chávez 48 51
# ('que', (157, 159)) who 164 167
# ('soviético', (73, 81)) Soviet 64 67
# ('venezuelanas', (128, 139)) Venezuelan 52 55
# ('venezuelanos', (404, 415)) Venezuelan 248 251
# ('Venezuela', (2, 10)) Venezuela 0 3
# ('Venezuela', (442, 450)) Venezuela 256 259
# ('Venezuela', (54, 62)) Venezuela 44 47
# ('Venezuela', (100, 108)) Venezuela 64 67
# ('Venezuela', (26, 34)) Venezuela 0 3
# ('Venezuela', (30, 38)) Venezuela 28 31
# ('Venezuela', (49, 57)) Venezuela 12 15
# ('Venezuela', (14, 22)) Venezuela 0 3
# ('Venezuela', (29, 37)) Venezuela 20 23
# ('dois', (57, 60)) two 60 63
# ('membros da oposição', (24, 42)) members of the opposition 12 15
# ('observadores', (67, 78)) observers 36 39
# ('às ruas', (239, 245)) the streets 128 131
# ('às ruas', (240, 246)) the streets 168 171
# ('sua', (321, 323)) its 228 231
# ('suas', (64, 67)) its 44 47
# ('que', (43, 45)) who 68 71
# ('que', (70, 72)) who 68 71
# ('que', (24, 26)) who 28 31
# ('que', (226, 228)) who 308 311
# ('que', (160, 162)) who 128 131
# ('que', (79, 81)) who 72 75
# ('rua', (60, 62)) street 48 51
# ('outros', (440, 445)) others 276 279
# ('Outros', (248, 253)) Others 144 147
# ('Outros', (0, 5)) others 4 7
# ('ele', (246, 248)) they 56 59
# ('Eles', (1, 4)) They 4 7
# ('eles', (142, 145)) they 128 131
# ('ela', (121, 123)) they 108 111
# ('estão', (82, 86)) they 56 59
# ('estão', (82, 86)) they 180 183
# ('eles', (71, 74)) they 48 51
# ('eles', (71, 74)) they 72 75
# ('eles', (71, 74)) they 96 99
# ('ele', (145, 147)) they 224 227
# ('podem', (210, 214)) they 164 167
# ('lhe', (143, 145)) they 260 263
# ('dizem', (120, 124)) they 76 79
# ('Eles', (65, 68)) They 68 71
# ('eles', (49, 52)) they 56 59
# ('seus', (319, 322)) their 208 211
# ('seus', (156, 159)) their 108 111
# ('seus', (156, 159)) their 156 159
# ('eles', (58, 61)) their 48 51
# ('seu', (41, 43)) their 36 39
# ('ele', (153, 155)) he 108 111
# ('ele', (153, 155)) he 172 175
# ('ele', (246, 248)) he 164 167
# ('Ele', (229, 231)) He 168 171
# ('ele', (145, 147)) he 92 95
# ('Ele', (370, 372)) He 232 235
# ('Ele', (370, 372)) he 216 219
# ('lhe', (143, 145)) he 132 135
# ('Ele', (0, 2)) He 0 3
# ('ele', (22, 24)) he 28 31
# ('ela', (121, 123)) she 136 139
# ('ela', (253, 255)) she 184 187
# ('ela', (89, 91)) she 60 63
# ('Ela', (0, 2)) She 0 3
# ('Ela', (0, 2)) She 0 3
# ('ela', (77, 79)) she 88 91
# ('ela', (229, 231)) she 184 187
# ('ela', (55, 57)) she 64 67
# ('ela', (59, 61)) she 52 55
# ('ela', (9, 11)) she 12 15
# ('que', (149, 151)) it 148 151
# ('alimentos', (395, 403)) food 340 343
# ('funcionários', (391, 402)) officials 252 255
# ('jornalistas', (247, 257)) journalists 156 159
# ('presos', (358, 363)) prisoners 220 223
# ('Apoiadores', (385, 394)) supporters 248 251
# ('manifestantes', (165, 177)) demonstrators 116 119
# ('políticos', (111, 119)) politicians 188 191
# ('colectivos', (183, 192)) colectivos 124 127
# ('funcionários', (53, 64)) employees 36 39
# ('venezuelanos', (46, 57)) Venezuelans 16 19
# ('funcionários', (259, 270)) employees 184 187
# ('oposição', (155, 162)) opposition 116 119
# ('cidadãos', (219, 226)) citizens 152 155
# ('livros', (147, 152)) books 96 99
# ('filmes', (156, 161)) movies 104 107
# ('7', (8, 8)) 7 8 11
# ('15', (409, 410)) 15,000 348 351
# ('15', (409, 410)) 15,000 312 315
# ('vice-presidente', (78, 92)) Vice President 40 43
# ('milhões', (401, 407)) millions 252 255
# ('20', (58, 59)) 20 56 59
# ('51', (39, 40)) 51 20 23
# ('oposição', (42, 49)) opposition 32 35
# ('líder', (33, 37)) leader 36 39
# ('vice-presidente', (53, 67)) vice president 44 47
# ('violações', (427, 435)) violations 264 267
# ('obrigando', (16, 24)) obliging 16 19
# ('demitir', (155, 161)) fire 140 143
# ('restringiram', (259, 270)) curbed 168 171
# ('em', (192, 193)) in 228 231
# ('confronto', (91, 99)) clash 44 47
# ('presas', (177, 182)) arrested 84 87
# ('marcha', (417, 422)) march 272 275
# ('tensões', (219, 225)) slaying 100 103
# ('protestos', (49, 57)) protests 48 51
# ('ordenou', (261, 267)) ordered 188 191
# ('morreu', (65, 70)) died 48 51
# ('sinistro', (188, 195)) sinister 140 143
# ('morreram', (21, 28)) died 16 19
# ('detenções', (87, 95)) Arrests 60 63
# ('espancando', (280, 289)) beating 180 183
# ('ameaçaram', (217, 225)) threatened 140 143
# ('perderam', (63, 70)) lost 44 47
# ('pressionando', (37, 48)) pressuring 28 31
# ('protestos', (3, 11)) protests 16 19
# ('presa', (17, 21)) arrested 20 23
# ('acusada', (25, 31)) charged 28 31
# ('manifestações', (99, 111)) demonstrations 92 95
# ('enviados', (163, 170)) sent 132 135
# ('penas', (233, 237)) sentences 184 187
# ('julgamento', (173, 182)) trial 156 159
# ('saíssem', (232, 238)) take 160 163
# ('implorar', (33, 40)) begging 12 15
# ('ultimato', (307, 314)) ultimatum 200 203
# ('disse', (95, 99)) said 60 63
# ('proibiu', (62, 68)) ban 64 67
# ('pedindo', (207, 213)) asking 148 151
# ('disse', (11, 15)) said 16 19
# ('dizendo', (123, 129)) saying 88 91
# ('prisão', (384, 389)) arrest 404 407
# ('coerção', (254, 260)) coercion 184 187
# ('polícia', (2, 8)) Police 0 3
# ('cidade', (13, 18)) city 12 15
# ('Lyon', (23, 26)) Lyon 20 23
# ('homem', (41, 45)) man 40 43
# ('pessoas', (130, 136)) people 88 91
# ('padaria', (169, 175)) bakery 112 115
# ('rua', (180, 182)) street 128 131
# ('Rue Victor Hugo', (192, 206)) Rue Victor Hugo 132 135
# ('francês', (229, 235)) French 156 159
# ('presidente', (218, 227)) President 160 163
# ('Emmanuel Macron', (237, 251)) Emmanuel Macron 164 167
# ('mim', (12, 14)) me 24 27
# ('Macron', (84, 89)) Macron 84 87
# ('mim', (12, 14)) I 124 127
# ('nesses', (140, 145)) these 144 147
# ('feridos', (147, 153)) injured 148 151
# ('suas', (160, 163)) their 156 159
# ('famílias', (165, 172)) families 160 163
# ('pessoas', (213, 219)) people 212 215
# ('hospital', (238, 245)) hospital 228 231
# ('mulheres', (259, 266)) women 248 251
# ('menina', (273, 278)) girl 280 283
# ('homens', (300, 305)) men 292 295
# ('homem', (2, 6)) man 4 7
# ('padaria', (76, 82)) bakery 52 55
# ('polícia', (87, 93)) Police 60 63
# ('o', (71, 71)) him 68 71
# ('europeu', (121, 127)) European 80 83
# ('europeu ou norte-africano', (121, 145)) North African 88 91
# ('homem', (115, 119)) male 96 99
# ('com', (107, 109)) his 104 107
# ('Ele', (255, 257)) He 188 191
# ('bike', (290, 293)) bicycle 216 219
# ('polícia', (2, 8)) Police 0 3
# ('pessoas', (19, 25)) people 12 15
# ('área', (43, 46)) area 28 31
# ('autoridades', (52, 62)) authorities 40 43
# ('que', (27, 29)) they 48 51
# ('Ampere-Victor Hugo', (121, 138)) Ampere-Victor Hugo 64 67
# ('metrô Ampere-Victor Hugo e Bellecour', (115, 150)) Bellecour metro 84 87
# ('estações', (103, 110)) stations 92 95
# ('islâmico', (22, 29)) Islamist 20 23
# ('atacantes', (33, 41)) attackers 40 43
# ('franceses', (9, 17)) French 0 3
# ('Soldados', (0, 7)) soldiers 4 7
# ('área', (52, 55)) area 28 31
# ('policial', (10, 17)) police 4 7
# ('fonte', (4, 8)) source 8 11
# ('padaria', (100, 106)) bakery 88 91
# ('esquina', (122, 128)) corner 104 107
# ('pensei', (22, 27)) I 24 27
# ('carro', (54, 58)) car 44 47
# ('Eva', (68, 70)) Eva 64 67
# ('estudante', (77, 85)) student 96 99
# ('que', (98, 100)) who 100 103
# ('mim', (40, 42)) me 32 35
# ('ela', (92, 94)) she 104 107
# ('AFP', (127, 129)) AFP 112 115
# ('distrito', (14, 21)) District 0 3
# ('Denis Broliquier', (24, 39)) Denis Broliquier 8 11
# ('Ele', (0, 2)) He 0 3
# ('padaria', (29, 35)) bakery 12 15
# ('geladeira', (16, 24)) fridge 24 27
# ('ele', (28, 30)) he 36 39
# ('franceses', (32, 40)) French 16 19
# ('policiais', (22, 30)) police 20 23
# ('policiais', (22, 30)) officers 24 27
# ('polícia', (2, 8)) Police 0 3
# ('área', (19, 22)) area 20 23
# ('francês', (23, 29)) French 0 3
# ('Interior', (14, 21)) Interior 4 7
# ('ministro', (2, 9)) Minister 8 11
# ('Christophe Castaner', (32, 50)) Christophe Castaner 12 15
# ('que', (59, 61)) he 24 27
# ('polícia', (94, 100)) police 40 43
# ('prefeitos', (81, 89)) prefects 44 47
# ('locais', (129, 134)) sites 76 79
# ('Paris', (188, 192)) Paris 96 99
# ('autoridade', (159, 168)) authority 108 111
# ('que', (59, 61)) which 116 119
# ('França', (253, 258)) France 144 147
# ('que', (195, 197)) it 160 163
# ('França', (2, 7)) France 0 3
# ('Estado Islâmico', (60, 74)) Islamic State 40 43
# ('grupo', (43, 47)) group 56 59
# ('Paris', (108, 112)) Paris 84 87
# ('pessoas', (127, 133)) people 100 103
# ('máximo', (24, 29)) more 116 119
# ('Lyon', (0, 3)) Lyon 0 3
# ('francesa', (30, 37)) French 24 27
# ('cidade', (23, 28)) city 28 31
# ('Paris', (49, 53)) Paris 36 39
# ('Marselha', (57, 64)) Marseille 44 47
# ('Feminina', (104, 111)) Women 80 83
# ('França', (47, 52)) France 16 19
# ('DW', (32, 33)) DW 12 15
# ('editores', (20, 27)) editors 24 27
# ('Você', (115, 118)) You 92 95
# ('francesa', (43, 50)) French 24 27
# ('Polícia', (35, 41)) police 28 31
# ('Facebook', (79, 86)) Facebook 44 47
# ('francesa', (199, 206)) French 140 143
# ('Polícia', (191, 197)) police 144 147
# ('AFP', (10, 12)) AFP 24 27
# ('Reuters', (15, 21)) Reuters 32 35
# ('feriu', (117, 121)) injured 80 83
# ('explosão', (89, 96)) blast 72 75
# ('explosão', (89, 96)) explosion 100 103
# ('levadas ao hospital', (227, 245)) taken to hospital 220 223
# ('fatal', (199, 203)) injuries 184 187
# ('feridos', (307, 313)) injured 296 299
# ('explosão', (11, 18)) explosion 16 19
# ('ferimentos', (96, 105)) injuries 56 59
# ('explosão', (305, 312)) explosion 188 191
# ('ataques', (97, 103)) attacks 76 79
# ('matando', (115, 121)) killing 92 95
# ('ferindo', (137, 143)) injuring 108 111
# ('quebradas', (103, 111)) blown 88 91
# ('suicídio', (62, 69)) suicide 36 39
# (None, (-1, -1)) opened a probe 168 171
# ('pediu', (10, 14)) urged 8 11
# ('instruiu', (63, 70)) instructed 32 35
# ('procurava', (28, 36)) searching 28 31
# ('Daguestão', (10, 18)) Dagestan 0 3
# ('Russa', (12, 16)) Russian 4 7
# ('República Russa do Daguestão', (2, 29)) Republic of Dagestan 8 11
# ('que', (32, 34)) which 24 27
# ('terra', (52, 56)) land 40 43
# ('montanhas', (62, 70)) mountains 52 55
# ('Rússia', (121, 126)) Russia 76 79
# ('norte do Cáucaso', (101, 116)) North Caucasus 92 95
# ('Chechénia', (135, 143)) Chechnya 104 107
# ('Geórgia', (149, 155)) Georgia 112 115
# ('Azerbaijão', (168, 177)) Azerbaijan 132 135
# ('Mar Cáspio', (189, 198)) Caspian Sea 156 159
# ('sua', (132, 134)) its 12 15
# ('picos', (5, 9)) peaks 16 19
# ('lugares', (35, 41)) places 28 31
# ('áreas', (54, 58)) areas 40 43
# ('helicóptero', (86, 96)) helicopter 60 63
# ('república', (101, 109)) republic 72 75
# ('sua', (132, 134)) its 92 95
# ('muçulmanos', (24, 33)) Muslim 8 11
# ('povos', (18, 22)) peoples 12 15
# ('vales', (61, 65)) valleys 36 39
# ('AFP', (26, 28)) AFP 8 11
# ('Aldeias', (44, 50)) Villages 20 23
# ('encostas', (65, 72)) hillsides 36 39
# ('Daguestão', (121, 129)) Dagestan 44 47
# ('interior', (98, 105)) interior 64 67
# ('ávaros', (3, 8)) Avars 4 7
# ('grupo', (29, 33)) group 24 27
# ('quinto', (68, 73)) fifth 48 51
# ('população', (78, 86)) population 60 63
# ('proporção', (99, 107)) proportion 80 83
# ('Dargins', (136, 142)) Dargins 100 103
# ('Kumyks', (145, 150)) Kumyks 108 111
# ('Lezgins', (154, 160)) Lezgins 116 119
# ('%', (174, 174)) cent 136 139
# ('russa', (189, 193)) Russians 148 151
# ('Laks', (211, 214)) Laks 168 171
# ('Tabasarans', (217, 226)) Tabasarans 176 179
# ('Nogai', (230, 234)) Nogai 184 187
# ('alguns', (255, 260)) few 208 211
# ('grupos', (273, 278)) groups 228 231
# ('república', (18, 26)) republic 4 7
# ('todos', (69, 73)) all 48 51
# ('Daguestão', (87, 95)) Dagestan 56 59
# ('povos', (78, 82)) peoples 68 71
# ('Rússia', (219, 224)) Russia 140 143
# ('província', (177, 185)) province 164 167
# ('república', (2, 10)) republic 4 7
# ('recursos', (112, 119)) fisheries 40 43
# ('mar Cáspio', (124, 133)) Caspian sea 84 87
# ('é', (148, 148)) it 104 107
# ('barões', (209, 214)) barons 152 155
# ('povo', (248, 251)) people 172 175
# ('Rússia', (282, 287)) Russia 196 199
# ('Daguestão', (2, 10)) Dagestan 0 3
# ('local', (18, 22)) place 16 19
# ('Imam Shamil', (41, 51)) Imam Shamil 24 27
# ('lutador', (65, 71)) fighter 44 47
# ('que', (73, 75)) who 48 51
# ('tribos', (135, 140)) tribesmen 84 87
# ('Chechénia', (145, 153)) Chechnya 92 95
# ('Daguestão', (160, 168)) Dagestan 100 103
# ('império russo', (184, 196)) Russian empire 124 127
# ('Seu', (199, 201)) His 136 139
# ('muitos', (233, 238)) many 160 163
# ('repúblicas', (249, 258)) republics 172 175
# ('AFP', (20, 22)) AFP 8 11
# ('federais', (45, 52)) Federal 20 23
# ('Tropas', (38, 43)) troops 24 27
# ('chechenos', (106, 114)) Chechen 52 55
# ('militantes', (95, 104)) militants 56 59
# ('bolcheviques', (10, 21)) Bolsheviks 8 11
# ('Cáucaso', (54, 60)) Caucasus 36 39
# ('Daguestão', (93, 101)) Dagestan 60 63
# ('soviética', (127, 135)) Soviet 76 79
# ('república', (117, 125)) republic 80 83
# ('Federação Russa', (156, 170)) Russian Federation 92 95
# ('seus', (207, 210)) its 124 127
# ('povos', (212, 216)) peoples 128 131
# ('seus', (207, 210)) their 156 159
# ('chechenos', (278, 286)) Chechen 160 163
# ('vizinhos', (269, 276)) neighbours 164 167
# ('outros', (299, 304)) others 176 179
# ('União Soviética', (16, 30)) Soviet Union 20 23
# ('república', (51, 59)) republic 36 39
# ('autoridades', (36, 46)) authorities 48 51
# ('Rússia', (82, 87)) Russia 64 67
# ('região', (96, 101)) region 80 83
# ('sua', (125, 127)) its 96 99
# ('armas', (245, 249)) Firearms 168 171
# ('Moscovo', (0, 6)) Moscow 0 3
# ('chechena', (64, 71)) Chechen 24 27
# ('outros', (78, 83)) others 48 51
# ('armas', (141, 145)) gun 84 87
# ('Budennovsk', (0, 9)) Budennovsk 0 3
# ('senhores da guerra', (19, 36)) warlords 20 23
# ('Chechênia', (62, 70)) Chechen 32 35
# ('Daguestão', (115, 123)) Dagestan 56 59
# ('capturaram', (163, 172)) they 96 99
# ('reféns', (186, 191)) hostages 112 115
# ('hospitais', (196, 204)) hospitals 120 123
# ('Daguestão', (115, 123)) Dagestani 132 135
# ('cidades', (210, 216)) towns 136 139
# ('Budennovsk', (221, 230)) Budennovsk 144 147
# ('Kizlyar', (234, 240)) Kizlyar 152 155
# ('Dezenas', (257, 263)) Scores 160 163
# ('AFP', (26, 28)) AFP 8 11
# ('Daguestão', (50, 58)) Dagestan 20 23
# ('forças', (85, 90)) forces 44 47
# ('Daguestão', (17, 25)) Dagestan 0 3
# ('muçulmanos', (3, 12)) Muslims 12 15
# ('que', (28, 30)) who 20 23
# ('checheno', (132, 139)) Chechen 76 79
# ('elementos', (181, 189)) elements 132 135
# ('wahhabista', (252, 261)) wahhabist 168 171
# ('organismo', (22, 30)) body 24 27
# ('Estado', (53, 58)) state 40 43
# ('partes', (76, 81)) parts 48 51
# ('Daguestão', (86, 94)) Dagestan 56 59
# ('Chechénia', (101, 109)) Chechnya 64 67
# ('muçulmanos', (124, 133)) Muslims 84 87
# ('Rússia', (171, 176)) Russia 108 111
# ('chechenos', (15, 23)) Chechen 0 3
# ('combatentes', (3, 13)) fighters 4 7
# ('Daguestão', (36, 44)) Dagestan 16 19
# ('russas', (88, 93)) Russian 56 59
# ('forças', (81, 86)) forces 60 63
# ('república', (2, 10)) republic 4 7
# ('russos', (65, 70)) Russian 36 39
# ('militares', (55, 63)) military 40 43
# ('república', (88, 96)) republic 56 59
# ('causa', (152, 156)) cause 108 111
# ('declara', (28, 34)) declares 20 23
# ('crime', (160, 164)) crime 124 127
# ('resistência', (107, 117)) resistance 76 79
# ('repelir', (74, 80)) repel 40 43
# ('crime', (174, 178)) crime 120 123
# ('armas', (245, 249)) Firearms 168 171
# ('assassinatos', (281, 292)) assassinations 184 187
# ('culpa', (35, 39)) blames 4 7
# ('dizem', (85, 89)) say 52 55
# ('capturaram', (163, 172)) seized 100 103
# ('morreram', (265, 272)) died 164 167
# ('ataques', (278, 284)) attacks 176 179
# ('ataques', (63, 69)) attacks 32 35
# ('assassinatos', (107, 118)) assassinations 52 55
# ('declarou', (41, 48)) declared 28 31
# ('declarou', (41, 48)) called 76 79
# ('cruzaram', (25, 32)) crossed 8 11
# ('reprimiram', (95, 104)) suppressed 68 71
# ('bombardeios', (26, 36)) bombings 20 23
# ('escaparam', (218, 226)) escaped 132 135
# ('Ela', (212, 214)) She 132 135
# ('Ela', (212, 214)) she 140 143
# ('prisão', (175, 180)) jail 112 115
# ('extremistas', (199, 209)) extremists 124 127
# ('britânica', (75, 83)) Britain 28 31
# ('serviços', (142, 149)) services 100 103
# ('autoridades', (176, 186)) authorities 132 135
# ('Theresa May', (20, 30)) Theresa May 8 11
# ('um', (140, 141)) one 100 103
# ('agressores', (147, 156)) assailants 112 115
# ('governo', (81, 87)) government 44 47
# ('britânico', (18, 26)) Britain 0 3
# ('ruas', (139, 142)) streets 92 95
# ('seguidor', (107, 114)) follower 80 83
# ('Estado Islâmico', (119, 133)) Islamic State 72 75
# ('polícia', (37, 43)) police 24 27
# ('cujo', (25, 28)) who 20 23
# ('paquistanês', (12, 22)) Pakistani 12 15
# ('britânico', (2, 10)) British 4 7
# ('deles', (237, 241)) them 160 163
# ('casa', (160, 163)) home 104 107
# ('sua', (156, 158)) his 100 103
# ('britânica', (146, 154)) Britain 92 95
# ('distrito', (108, 115)) district 84 87
# ('Erica Gasparri', (157, 170)) Erica Gasparri 112 115
# ('capital', (138, 144)) capital 104 107
# ('carrinha', (85, 92)) van 44 47
# ('Polícia da Grande Manchester', (199, 226)) Greater Manchester Police 164 167
# ('faca', (100, 103)) knife 60 63
# ('três', (180, 183)) three 136 139
# ('mãe', (173, 175)) mother 128 131
# ('homens', (314, 319)) men 260 263
# ('Um', (368, 369)) One 248 251
# ('locais', (184, 189)) residents 120 123
# ('pessoas', (151, 157)) people 96 99
# ('”', (149, 149)) ” 88 91
# ('porta-voz', (111, 119)) spokesman 68 71
# ('homens', (314, 319)) men 208 211
# ('mulheres', (297, 304)) women 196 199
# ('pessoas', (151, 157)) people 184 187
# ('polícia', (124, 130)) police 172 175
# ('Serviços de segurança britânicos', (0, 31)) British Security Services 0 3
# ('LONDRES', (0, 6)) LONDON 0 3
# ('britânicos', (51, 60)) Britain 28 31
# ('serviços', (29, 36)) services 44 47
# ('deles', (237, 241)) their 68 71
# ('coração', (204, 210)) heart 136 139
# ('Londres', (215, 221)) London 144 147
# ('parque', (307, 312)) park 228 231
# ('Ela', (321, 323)) She 236 239
# ('ele', (280, 282)) he 204 207
# ('crianças', (292, 299)) kids 212 215
# ('ele', (280, 282)) she 168 171
# ('Abedi', (249, 253)) Abedi 180 183
# ('Barking', (206, 212)) Barking 152 155
# ('mídia', (223, 227)) media 164 167
# ('ele', (280, 282)) she 244 247
# ('ele', (280, 282)) him 252 255
# ('que', (44, 46)) he 44 47
# ('BBC', (40, 42)) BBC 36 39
# ('polícia', (58, 64)) them 64 67
# ('polícia', (58, 64)) police 52 55
# ('Grã-Bretanha', (144, 155)) Britain 100 103
# ('terroristas', (118, 128)) terrorist 88 91
# ('homem', (223, 227)) man 128 131
# ('seu', (167, 169)) his 112 115
# ('agressor', (258, 265)) attacker 176 179
# ('amigo', (232, 236)) friend 160 163
# ('loja', (180, 183)) store 176 179
# ('metrô de Londres', (215, 230)) London Underground 196 199
# ('Londres', (61, 67)) London 44 47
# ('Grã-Bretanha', (70, 81)) Britain 52 55
# ('London Bridge', (43, 55)) London Bridge 32 35
# ('os', (248, 249)) them 244 247
# ('polícia', (382, 388)) police 256 259
# ('polícia', (2, 8)) Police 0 3
# ('agentes', (12, 18)) officers 20 23
# ('aqueles', (117, 123)) those 76 79
# ('veículos', (288, 295)) vehicle 176 179
# ('locatários', (314, 323)) renters 192 195
# ('venda', (214, 218)) firms 224 227
# ('leste de Londres', (90, 105)) east London 48 51
# ('polícia', (124, 130)) police 64 67
# ('London Bridge', (120, 132)) London Bridge 76 79
# ('que', (146, 148)) he 100 103
# ('trabalhador', (116, 126)) worker 92 95
# ('homem-bomba', (89, 99)) bomber 76 79
# ('seus', (62, 65)) their 36 39
# ('britânico', (38, 46)) Britain 4 7
# ('homem-bomba', (89, 99)) bomber 136 139
# ('Abedi', (185, 189)) Abedi 116 119
# ('autoridades', (163, 173)) authorities 108 111
# ('MI5', (48, 50)) MI5 28 31
# ('serviço', (6, 12)) service 24 27
# ('funcionário', (8, 18)) official 12 15
# ('conservador', (20, 30)) Conservative 8 11
# ('ele', (175, 177)) he 300 303
# ('sua', (300, 302)) their 284 287
# ('autoridades', (274, 284)) authorities 268 271
# ('sua', (256, 258)) their 248 251
# ('pessoas', (238, 244)) people 240 243
# ('muito', (21, 25)) lot 228 231
# ('Downing Street', (74, 87)) Downing Street 48 51
# ('VOA', (40, 42)) VOA 20 23
# ('pregador', (293, 300)) preacher 208 211
# ('Ahmad Musa Jibril', (320, 336)) Ahmad Musa Jibril 212 215
# ('seguidor', (281, 288)) follower 192 195
# ('americano', (310, 318)) American 200 203
# ('Musa Jibril', (27, 37)) Musa Jibril 36 39
# ('ele', (47, 49)) he 52 55
# ('clérigo', (361, 367)) cleric 252 255
# ('Ele', (1, 3)) He 4 7
# ('BBC', (53, 55)) BBC 64 67
# ('Liguei', (59, 64)) I 76 79
# ('Manchester', (70, 79)) Manchester 36 39
# ('que', (130, 132)) he 96 99
# ('figura', (187, 192)) figure 124 127
# ('Salman Abedi', (10, 21)) Salman Abedi 8 11
# ('suicida', (59, 65)) bomber 24 27
# ('Manchester', (69, 78)) Manchester 40 43
# ('polícia', (58, 64)) police 44 47
# ('legisladores', (113, 124)) lawmakers 72 75
# ('Liguei', (59, 64)) I 108 111
# ('senhor', (114, 119)) gentleman 124 127
# ('Liguei', (59, 64)) I 132 135
# ('ele', (175, 177)) him 140 143
# ('nossa', (141, 145)) our 148 151
# ('Liguei', (59, 64)) I 164 167
# ('ele', (175, 177)) he 172 175
# ('Liguei', (59, 64)) I 196 199
# ('minha', (203, 207)) my 204 207
# ('Liguei', (59, 64)) I 216 219
# ('recrutador', (308, 317)) recruiter 208 211
# ('foi', (130, 132)) IS 204 207
# ('filhos', (43, 48)) children 52 55
# ('pai', (20, 22)) father 28 31
# ('Estado Islâmico', (175, 189)) Islamic State 120 123
# ('foi', (130, 132)) he 100 103
# ('Londres', (248, 254)) London 160 163
# ('polícia', (217, 223)) police 148 151
# ('Anjem Choudary', (289, 302)) Anjem Choudary 184 187
# ('pregador', (272, 279)) preacher 180 183
# ('Paquistão', (68, 76)) Pakistan 72 75
# ('requerentes', (44, 54)) seekers 64 67
# ('líder', (11, 15)) ringleader 16 19
# ('pais', (3, 6)) parents 4 7
# ('muçulmana', (424, 432)) Muslim 320 323
# ('me', (414, 415)) I 300 303
# ('Mamãe', (401, 405)) Mummy 296 299
# ('casa', (386, 389)) home 276 279
# ('crianças', (292, 299)) children 268 271
# ('ele', (280, 282)) her 260 263
# ('Abedi', (155, 159)) Abedi 96 99
# ('uma', (183, 185)) one 132 135
# ('cidade', (166, 171)) city 116 119
# ('que', (112, 114)) who 76 79
# ('mesquitas', (42, 50)) mosque 20 23
# ('comunitários', (24, 35)) community 12 15
# ('Manchester', (55, 64)) Manchester 32 35
# ('líderes', (16, 22)) leaders 24 27
# ('Salman Abedi', (80, 91)) Salman Abedi 48 51
# ('vizinhos', (68, 75)) neighbors 40 43
# ('líbio', (106, 110)) Libyan 72 75
# ('britânico', (96, 104)) British 64 67
# ('funcionários', (65, 76)) officials 48 51
# ('Theresa May', (38, 48)) Theresa May 20 23
# ('britânica', (28, 36)) British 8 11
# ('chefes', (36, 41)) chiefs 28 31
# ('empresas', (292, 299)) businesses 192 195
# ('provedores', (267, 276)) providers 176 179
# ('seus', (353, 356)) their 216 219
# ('que', (222, 224)) that 196 199
# ('residente', (331, 339)) resident 232 235
# ('27 anos', (11, 17)) 27-year-old 4 7
# ('Barking', (181, 187)) Barking 132 135
# ('onde', (211, 214)) where 140 143
# ('leste de Londres', (193, 208)) east London 116 119
# ('distrito', (169, 176)) district 124 127
# ('parque', (276, 281)) park 188 191
# ('polícia', (316, 322)) police 216 219
# ('sua', (156, 158)) he 144 147
# ('crianças', (232, 239)) children 160 163
# ('amigo', (10, 14)) friend 8 11
# ('líder', (19, 23)) ringleader 20 23
# ('homem', (104, 108)) man 104 107
# ('lanchonete', (161, 170)) outlet 160 163
# ('líder', (164, 168)) ringleader 100 103
# ('Polícia', (10, 16)) Police 8 11
# ('moradores', (26, 34)) locals 16 19
# ('polícia', (48, 54)) police 28 31
# ('militante', (268, 276)) militant 188 191
# ('policial', (13, 20)) police 12 15
# ('serviços', (186, 193)) services 136 139
# ('o', (161, 161)) him 164 167
# ('Manchester', (71, 80)) Manchester 40 43
# ('Grã-Bretanha', (83, 94)) Britain 48 51
# ('policial', (13, 20)) officer 16 19
# ('mesquita de Didsbury', (46, 65)) Didsbury mosque 28 31
# ('ataque', (173, 178)) attack 124 127
# ('atentado', (127, 134)) bombing 104 107
# ('identificarem', (246, 258)) identify 160 163
# ('atentado', (50, 57)) bombing 44 47
# ('ataque', (144, 149)) attack 108 111
# ('ataque', (70, 75)) attack 64 67
# ('ataque', (20, 25)) attack 36 39
# ('ataques', (110, 116)) attacks 92 95
# ('observação', (149, 158)) watch 88 91
# ('detidas', (165, 171)) detained 108 111
# ('prendeu', (272, 278)) arrested 176 179
# ('lançaram', (36, 43)) released 276 279
# ('homens', (32, 37)) Taliban 32 35
# ('homens armados', (32, 45)) gunmen 36 39
# ('homens-bomba', (49, 60)) bombers 48 51
# ('acampamento Shorabak', (81, 100)) Camp Shorabak 56 59
# ('província de Helmand', (106, 125)) Helmand Province 68 71
# ('Afeganistão', (131, 141)) Afghanistan 80 83
# ('Eles', (0, 3)) They 0 3
# ('afegãos', (25, 31)) Afghan 12 15
# ('soldados', (16, 23)) soldiers 16 19
# ('15', (50, 51)) 15 32 35
# ('insurgentes', (6, 16)) insurgents 4 7
# ('23', (13, 14)) 23 8 11
# ('Vinte', (0, 4)) Twenty 0 3
# ('atacaram', (70, 77)) attacked 52 55
# ('mataram', (5, 11)) killed 4 7
# ('feriram', (35, 41)) injured 24 27
# ('mortos', (24, 29)) killed 12 15
# ('É', (0, 0)) s 8 11
# ('você', (23, 26)) you 24 27
# (None, (-1, -1)) we 4 7
# ('alguém', (148, 153)) anyone 116 119
# ('país', (20, 23)) country 16 19
# ('país', (246, 249)) country 200 203
# ('forças de segurança', (130, 148)) security forces 76 79
# ('ao governo', (120, 129)) the government 80 83
# ('o governo', (179, 187)) the government 144 147
# ('Landaeta', (0, 7)) Landaeta 0 3
# ('Landaeta', (166, 173)) Landaeta 132 135
# ('Landaeta', (99, 106)) Landaeta 124 127
# ('o Centro Europeu de Prevenção e Controlo de Doenças', (114, 164)) the European Centre for Disease Prevention and Control 88 91
# ('Hospital Universitário de Caracas', (50, 82)) the Hospital Universitario de Caracas 32 35
# ('da Universidade de Los Andes', (59, 86)) the Universidad de Los Andes 28 31
# ('Maria Eugenia Landaeta', (85, 106)) Maria Eugenia Landaeta 56 59
# ('venezuelanos', (103, 114)) Venezuelans 72 75
# ('venezuelanos', (193, 204)) Venezuelans 148 151
# ('dengue', (135, 140)) dengue 184 187
# ('dengue', (135, 140)) dengue 88 91
# ('dengue', (75, 80)) dengue 44 47
# ('Táchira', (102, 108)) Tachira 56 59
# ('estado', (92, 97)) state 60 63
# ('febre', (106, 110)) fever 80 83
# ('dengue', (236, 241)) fever 188 191
# ('dengue', (135, 140)) fever 92 95
# ('dengue', (75, 80)) fever 48 51
# ('Aragua', (81, 86)) Aragua 52 55
# ('Perez', (0, 4)) Perez 0 3
# ('Perez', (143, 147)) Perez 100 103
# ('Perez', (172, 176)) Perez 132 135
# ('África', (158, 163)) Africa 124 127
# ('África', (217, 222)) Africa 156 159
# ('doenças', (142, 148)) diseases 116 119
# ('doenças', (27, 33)) diseases 20 23
# ('doenças', (70, 76)) diseases 60 63
# ('doenças', (289, 295)) diseases 216 219
# ('doenças', (9, 15)) diseases 4 7
# ('doença', (40, 45)) disease 28 31
# ('doença', (135, 140)) disease 92 95
# ('Nancy Perez', (21, 31)) Nancy Perez 20 23
# ('Ela', (0, 2)) She 0 3
# ('Ela', (0, 2)) she 68 71
# ('Ela', (143, 145)) She 100 103
# ('que', (14, 16)) it 164 167
# ('paracetamol', (46, 56)) acetaminophen 40 43
# ('doenças', (70, 76)) diseases 60 63
# ('chikungunya', (119, 129)) chikungunya 156 159
# ('dengue', (236, 241)) fever 188 191
# ('surto', (145, 149)) outbreak 108 111
# ('É', (118, 118)) s 84 87
# (None, (-1, -1)) you 28 31
# ('nossos', (141, 146)) our 104 107
# (None, (-1, -1)) we 352 355
# (None, (-1, -1)) we 392 395
# (None, (-1, -1)) we 8 11
# ('sua', (405, 407)) Her 304 307
# ('Hugo Chávez', (86, 96)) Hugo Chávez 60 63
# ('me', (100, 101)) I 164 167
# ('o governo', (219, 227)) the government 176 179
# ('o governo', (219, 227)) the government 268 271
# ('governo', (96, 102)) government 88 91
# ('Conselho Eleitoral Nacional', (53, 79)) National Elections Council 80 83
# ('do governo', (81, 90)) the government 64 67
# ('CNE', (107, 109)) CNE 92 95
# ('CNE', (14, 16)) CNE 12 15
# ('cancro', (107, 112)) cancer 80 83
# ('cuja', (46, 49)) whose 44 47
# ('a Assembleia Constituinte', (28, 52)) the Constituent Assembly 28 31
# ('o Supremo Tribunal', (51, 68)) the Supreme Tribunal 40 43
# ('Conselho Eleitoral', (537, 554)) Elections Council 424 427
# ('nos', (137, 139)) U.S.- 32 35
# ('Miraflores', (292, 301)) Miraflores 204 207
# ('venezuelana', (145, 155)) Venezuelan 100 103
# ('ir', (317, 318)) they 152 155
# ('ir', (317, 318)) they 248 251
# ('concorreram', (92, 102)) they 56 59
# ('É', (118, 118)) they 56 59
# ('sua', (405, 407)) their 292 295
# ('de', (301, 302)) their 288 291
# ('que', (13, 15)) It 0 3
# ('que', (213, 215)) it 216 219
# ('pessoas', (6, 12)) people 4 7
# ('Essas pessoas', (0, 12)) These people 0 3
# ('o', (191, 191)) the 188 191
# ('vencedores', (248, 257)) winners 192 195
# ('2012', (6, 9)) 2012 4 7
# ('governo', (282, 288)) governing 212 215
# ('partido', (271, 277)) party 216 219
# ('pessoas', (339, 345)) people 252 255
# ('2,4 milhões', (289, 299)) 2.4 million 224 227
# ('pessoas', (304, 310)) people 240 243
# ('cometer fraude numa eleição em', (57, 86)) commit fraud in an election 32 35
# ('cometer fraude numa eleição em', (57, 86)) commit fraud in an election 32 35
# ('Juan Manuel Santos', (253, 270)) Juan Manuel Santos 256 259
# ('Tarek William Saab', (31, 48)) Tarek William Saab 16 19
# ('Nicolás Maduro', (27, 40)) Nicolas Maduro 16 19
# ('Nicolás Maduro', (151, 164)) Nicolás Maduro 84 87
# ('Maduro', (222, 227)) Maduro 172 175
# ('Maduro', (307, 312)) Maduro 292 295
# ('tribunal', (129, 136)) court 92 95
# ('militar', (96, 102)) military 56 59
# ('sua', (68, 70)) me 164 167
# ('os', (183, 184)) those 212 215
# ('eu', (201, 202)) I 148 151
# ('sua', (68, 70)) his 40 43
# ('o governo', (4, 12)) the government 8 11
# ('Saab', (145, 148)) Saab 112 115
# ('Saab', (205, 208)) Saab 148 151
# ('Yanin Pernía', (425, 436)) Yanin Pernía 292 295
# ('José Blanco', (440, 450)) José Blanco 304 307
# ('Brigada do GNB', (13, 26)) GNB Brigade 0 3
# ('Hector Armando Hernández Da Costa', (28, 60)) Hector Armando Hernández Da Costa 12 15
# ('Pedro Zambrano', (304, 317)) Pedro Zambrano 208 211
# ('Alejandro Pérez', (379, 393)) Alejandro Pérez 256 259
# ('Brayan Oropeza', (396, 409)) Brayan Oropeza 268 271
# ('Luis Guerra', (412, 422)) Luis Guerra 280 283
# ('14', (107, 108)) 14 72 75
# ('da Guarda Nacional Bolivariana', (136, 165)) the Bolivarian National Guard 84 87
# ('Guarda Nacional Bolivariana', (344, 370)) Bolivarian National Guard 224 227
# ('FANB', (332, 335)) FANB 240 243
# ('FBI', (63, 65)) FBI 52 55
# ('Flórida', (115, 121)) Florida 92 95
# ('Interpol', (32, 39)) Interpol 44 47
# ('Interpol', (223, 230)) Interpol 164 167
# ('das Forças Armadas Nacionais Bolivarianas', (289, 329)) the Bolivarian National Armed Forces 216 219
# ('alguns', (188, 193)) some 132 135
# ('Caracas', (179, 185)) Caracas 116 119
# ('dos Estados Unidos', (14, 31)) the United States 20 23
# ('colombiana', (229, 238)) Colombian 220 223
# ('Venezuela', (16, 24)) Venezuelan 196 199
# ('venezuelano', (19, 29)) Venezuelan 4 7
# ('Venezuela', (16, 24)) Venezuela 0 3
# (None, (-1, -1)) s 8 11
# ('Juan Requesens', (278, 291)) Juan Requesens 192 195
# ('Juan Requesens', (26, 39)) Juan Requesens 20 23
# ('Juan Requesens', (189, 202)) Juan Requesens 136 139
# ('sua', (45, 47)) its 36 39
# ('e', (128, 128)) They 144 147
# ('procurador-geral', (2, 17)) Attorney General 8 11
# ('34', (180, 181)) 34 104 107
# ('13 de agosto', (236, 247)) August 13 176 179
# ('Brayan', (396, 401)) lawmaker 188 191
# (None, (-1, -1)) Division General 248 251
# ('coronel', (296, 302)) Colonel 204 207
# ('General', (2, 8)) General 8 11
# ('promotor', (135, 142)) prosecutor 100 103
# ('O', (133, 133)) The 96 99
# ('4 de agosto', (188, 198)) August 4 116 119
# ('4 de agosto', (191, 201)) August 4 128 131
# ('81º', (120, 122)) 81st 72 75
# ('34', (31, 32)) 34 20 23
# ('27', (163, 164)) 27 104 107
# ('pessoas', (34, 40)) people 24 27
# ('presidente', (2, 11)) President 12 15
# ('forças de inteligência', (86, 107)) intelligence forces 48 51
# ('indiciados', (256, 265)) indicted 324 327
# ('detido', (73, 78)) detained 40 43
# ('acusado', (45, 51)) charged 32 35
# ('nas investigações', (76, 92)) the investigations 68 71
# ('na tentativa de assassinato', (328, 354)) the assassination attempt 232 235
# ('tentativa fracassada de assassinato', (62, 96)) failed assassination attempt 44 47
# ('traição', (66, 72)) treason 48 51
# ('homicídio', (122, 130)) homicide 88 91
# ('terrorismo', (75, 84)) terrorism 56 59
# ('associação para cometer um crime', (87, 118)) association to commit a crime 64 67
# ('polícia', (221, 227)) police 156 159
# ('Tamerlan', (172, 179)) Tamerlan 120 123
# ('condenado', (161, 169)) he 104 107
# ('Boston', (74, 79)) Boston 56 59
# ('prisão', (48, 53)) prison 44 47
# ('Dzhokhar Tsarnaev', (0, 16)) Dzhokhar Tsarnaev 0 3
# ('Quirguistão', (266, 276)) Kyrgyzstan 168 171
# ('agente', (208, 213)) Agent 152 155
# ('Timothy McElroy', (231, 245)) Timothy McElroy 156 159
# ('estudante', (171, 179)) student 108 111
# ('Seu', (97, 99)) his 160 163
# ('ataques', (88, 94)) bombers 124 127
# ('McElroy', (31, 37)) McElroy 48 51
# ('Matanov', (36, 42)) Matanov 20 23
# ('Marianne Bowler', (8, 22)) Marianne Bowler 8 11
# ('juíza', (2, 6)) Magistrate 0 3
# ('260', (272, 274)) 260 192 195
# ('pessoas', (248, 254)) people 172 175
# ('Ele', (167, 169)) He 96 99
# ('autoridades', (120, 130)) officials 72 75
# ('Khairullozhon Matanov', (0, 20)) Khairullozhon Matanov 0 3
# ('Boston', (229, 234)) Boston 120 123
# ('homens', (147, 152)) men 96 99
# ('que', (111, 113)) who 88 91
# ('Quincy', (138, 143)) Quincy 100 103
# ('FBI', (374, 376)) FBI 260 263
# ('Hayden', (188, 193)) Hayden 136 139
# ('seu', (115, 117)) his 72 75
# ('Dzhokhar', (104, 111)) Dzhokhar 64 67
# ('Matanov', (0, 6)) Matanov 0 3
# ('tribunal', (22, 29)) court 16 19
# ('prisão', (89, 94)) prison 48 51
# ('Seu', (97, 99)) His 60 63
# ('ele', (120, 122)) he 72 75
# ('Estados Unidos', (135, 148)) United States 84 87
# ('sua', (54, 56)) his 24 27
# ('advogado', (38, 45)) lawyer 28 31
# ('sua', (214, 216)) his 44 47
# ('advogado', (90, 97)) attorney 48 51
# ('homem', (136, 140)) man 80 83
# ('se', (86, 87)) himself 92 95
# ('sua', (214, 216)) his 104 107
# ('motorista', (191, 199)) driver 124 127
# ('sua', (214, 216)) his 132 135
# ('Ela', (0, 2)) She 0 3
# ('promotores', (3, 12)) Prosecutors 0 3
# ('Matanov', (27, 33)) Matanov 8 11
# ('seu', (46, 48)) his 40 43
# ('Matanov', (305, 311)) Matanov 200 203
# ('Tsarnaevs', (341, 349)) Tsarnaevs 228 231
# ('que', (91, 93)) he 76 79
# ('FBI', (180, 182)) FBI 100 103
# (',', (102, 102)) bombers 56 59
# ('Matanov', (60, 66)) Matanov 32 35
# ('documentos', (23, 32)) papers 16 19
# ('Hayden', (0, 5)) Hayden 0 3
# ('Tamerlan Tsarnaev', (126, 142)) Tamerlan Tsarnaev 84 87
# ('irmão', (119, 123)) brother 76 79
# ('suas', (121, 124)) his 68 71
# ('chechena', (163, 170)) Chechen 92 95
# ('Boston', (85, 90)) Boston 28 31
# ('bomba', (76, 80)) Bomb 32 35
# ('Quirguistão', (12, 22)) Kyrgyzstan 0 3
# ('Nacional', (0, 7)) National 4 7
# ('Quirguistão', (14, 24)) Kyrgyzstan 12 15
# ('investigadores', (91, 104)) investigators 60 63
# ('BOSTON', (0, 5)) BOSTON 0 3
# ('cidadão', (3, 9)) citizen 4 7
# ('FBI', (227, 229)) FBI 144 147
# ('que', (17, 19)) who 12 15
# ('agente', (3, 8)) agent 8 11
# ('advogado', (77, 84)) attorney 64 67
# ('seu', (34, 36)) his 28 31
# ('ele', (92, 94)) he 56 59
# ('sua', (54, 56)) his 40 43
# ('FBI', (13, 15)) FBI 4 7
# ('Matanov', (16, 22)) Matanov 0 3
# ('Matanov', (115, 121)) Matanov 80 83
# ...
# ('71', (172, 173)) 71 116 119
# ('basco', (313, 317)) Basque 208 211
# ('grupo', (295, 299)) group 216 219
# ('ETA', (326, 328)) ETA 220 223
# ('Café Rolando', (2, 13)) Rolando Cafe 4 7
# ('4', (53, 53)) 4 24 27
# ('Calle del Correo', (36, 51)) Calle del Correo 28 31
# ('Madrid', (59, 64)) Madrid 44 47
# ('Direção Geral de Segurança', (76, 101)) General Directorate of Security 64 67
# ('sede', (104, 107)) headquarters 88 91
# ('Espanhola', (120, 128)) Spanish 100 103
# ('Polícia', (112, 118)) Police 104 107
# ('Era', (131, 133)) It 112 115
# ('membros', (164, 170)) members 132 135
# ('polícia', (175, 181)) police 144 147
# ('polícia', (175, 181)) force 148 151
# ('serviços', (189, 196)) services 160 163
# ('bomba', (2, 6)) bomb 4 7
# ('prédio', (35, 40)) building 36 39
# ('pessoas', (136, 142)) people 104 107
# ('restaurante vizinho El Tobogan', (154, 183)) El Tobogan restaurant 128 131
# ('dois', (380, 383)) two 168 171
# ('quais', (218, 222)) whom 176 179
# ('edifícios', (290, 298)) buildings 228 231
# ('Geral de Segurança', (351, 368)) General Directorate of Security 260 263
# ('carros', (385, 390)) cars 288 291
# ('bomba', (453, 457)) bomb 320 323
# ('parte', (483, 487)) part 328 331
# ('Café Rolando', (500, 511)) Rolando Cafe 340 343
# ('os hóspedes', (515, 525)) guests 372 375
# ('pensão', (530, 535)) pension 388 391
# ('polícia', (592, 598)) police 448 451
# ('Dois', (0, 3)) Two 0 3
# ('12', (9, 10)) 12 12 15
# ('11', (34, 35)) 11 28 31
# ('membros', (50, 56)) members 48 51
# ('Polícia', (126, 132)) police 60 63
# ('força', (61, 65)) force 64 67
# ('dois', (118, 121)) two 96 99
# ('Espanhola', (143, 151)) Spanish 108 111
# ('Polícia Política', (126, 141)) Political Police 112 115
# ('funcionários', (173, 184)) employees 136 139
# ('clientes', (188, 195)) customers 144 147
# ('café', (200, 203)) cafe 156 159
# ('vítima', (226, 231)) victim 172 175
# ('liderança', (2, 10)) leadership 4 7
# ('ETA', (15, 17)) ETA 12 15
# ('sua', (118, 120)) their 88 91
# ('café', (200, 203)) cafe 136 139
# ('policiais', (229, 237)) police 152 155
# ('agentes', (221, 227)) agents 156 159
# ('grupo', (270, 274)) group 184 187
# ('membros', (288, 294)) members 200 203
# ('organização', (314, 324)) organisation 216 219
# ('os', (293, 294)) those 304 307
# ('país', (510, 513)) country 332 335
# ('Blas Piñar', (521, 530)) Blas Piñar 348 351
# ('ministro', (569, 576)) Minister 384 387
# ('Carlos Arias Navarro', (578, 597)) Carlos Arias Navarro 388 391
# ('alguns', (57, 62)) some 40 43
# ('infra-estrutura', (201, 215)) far-right 64 67
# ('polícia', (114, 120)) police 84 87
# ('ETA', (150, 152)) ETA 108 111
# ('grupo', (220, 224)) group 144 147
# ('Madrid', (229, 234)) Madrid 164 167
# ('polícia', (114, 120)) police 180 183
# ('Partido Comunista de Espanha', (277, 304)) Communist Party of Spain 196 199
# ('PCE', (307, 309)) PCE 216 219
# ('PCE', (307, 309)) PCE 256 259
# ('polícia', (253, 259)) police 284 287
# ('polícia', (253, 259)) officers 288 291
# ('aconselhando-os', (445, 459)) them 312 315
# ('Café Rolando', (473, 484)) Rolando Cafe 336 339
# ('prédio', (514, 519)) building 360 363
# ('Esquerdistas', (0, 11)) Leftists 0 3
# ('ETA', (48, 50)) ETA 24 27
# ('Eva Forest', (75, 84)) Eva Forest 44 47
# ('esposa', (86, 91)) wife 56 59
# ('dramaturgo', (96, 105)) playwright 72 75
# ('Alfonso Sastre', (117, 130)) Alfonso Sastre 76 79
# ('Mari Luz Fernandez', (132, 149)) Mari Luz Fernandez 88 91
# ('la', (217, 218)) her 104 107
# ('parentes', (158, 165)) relatives 108 111
# ('Lidia Falcón', (167, 178)) Lidia Falcón 116 119
# ('teatro', (193, 198)) theatre 132 135
# ('diretor', (182, 188)) director 136 139
# ('Vicente Sainz de la Peña', (200, 223)) Vicente Sainz de la Peña 140 143
# ('piloto', (272, 277)) worker 168 171
# ('Antonio Durán', (256, 268)) Antonio Durán 172 175
# ('piloto', (272, 277)) pilot 184 187
# ('Bernardo Badell', (279, 293)) Bernardo Badell 188 191
# ('sua', (297, 299)) his 200 203
# ('esposa', (301, 306)) wife 204 207
# ('María del Carmen Nadal', (308, 329)) María del Carmen Nadal 208 211
# ('atriz', (334, 338)) actress 232 235
# ('María Paz Ballesteros', (340, 360)) María Paz Ballesteros 236 239
# ('escritor', (366, 373)) writer 260 263
# ('Eliseo Bayo', (375, 385)) Eliseo Bayo 264 267
# ('tribunais', (432, 440)) courts 304 307
# ('réus', (478, 481)) defendants 332 335
# ('Eva Forest', (496, 505)) Eva Forest 344 347
# ('Mari Luz Fernandez', (509, 526)) Mari Luz Fernandez 356 359
# ('prisão', (544, 549)) prison 376 379
# ('foram', (558, 562)) they 384 387
# ('Luis Carrero Blanco', (607, 625)) Luis Carrero Blanco 420 423
# ('Forest', (500, 505)) Forest 460 463
# ('Luz Fernandez', (514, 526)) Luz Fernandez 468 471
# ('Rolando', (714, 720)) Rolando 492 495
# ('foram', (558, 562)) they 508 511
# ('presos', (799, 804)) prisoners 564 567
# ('Lidia Falcón', (826, 837)) Lidia Falcón 580 583
# ('Eva Forest', (496, 505)) Eva Forest 604 607
# ('Forest', (657, 662)) Forest 624 627
# ('Rolando', (714, 720)) Rolando 648 651
# ('governo', (2, 8)) government 4 7
# ('Juan Manuel Galarraga Mendizabal', (107, 138)) Juan Manuel Galarraga Mendizabal 68 71
# ('que', (81, 83)) who 84 87
# ('que', (81, 83)) they 88 91
# ('ETA', (191, 193)) ETA 116 119
# ('figura', (165, 170)) figure 120 123
# ('janelas', (323, 329)) windows 244 247
# ('teto', (492, 495)) ceiling 356 359
# ('comunicado', (97, 106)) statement 80 83
# ('ataque', (47, 52)) attack 24 27
# ('matou', (147, 151)) killed 96 99
# ('feriu', (166, 170)) wounded 112 115
# ('explodiu', (44, 51)) exploded 44 47
# ('explosão', (199, 206)) explosion 160 163
# ('mortos', (241, 246)) dead 192 195
# ('danos', (267, 271)) damage 216 219
# ('quebrando', (310, 318)) shattering 236 239
# ('danos', (267, 271)) destroyed 308 311
# ('desabamento', (468, 478)) collapse 364 367
# ('feridos', (551, 557)) injured 400 403
# ('mortos', (12, 17)) killed 20 23
# ('mortos', (12, 17)) injured 40 43
# ('mortos', (12, 17)) wounded 80 83
# ('morreu', (233, 238)) died 176 179
# ('ataques', (369, 375)) attacks 240 243
# ('presos', (58, 63)) arrested 32 35
# ('acusadas', (564, 571)) charged 392 395
# ('ferimentos', (259, 268)) injuries 192 195
# ('ataque', (369, 374)) attack 372 375
# ('ataque', (49, 54)) attack 52 55
# ('assassinato', (592, 602)) assassination 412 415
# ('libertaram', (464, 473)) released 516 519
# ('realizado', (279, 287)) carried out 188 191
# ('colocada', (12, 19)) placed 12 15
# ('emitiu', (87, 92)) issued 72 75
# ('suspeito', (33, 40)) suspect 40 43
# ('Boston', (78, 83)) Boston 28 31
# ('suspeito', (26, 33)) Suspect 24 27
# ('tribunal', (3, 10)) court 4 7
# ('Tribunal', (0, 7)) Court 0 3
# ('linha', (32, 36)) line 24 27
# ('Tsarnaev', (119, 126)) them 152 155
# ('promotores', (3, 12)) Prosecutors 0 3
# ('casa', (139, 142)) home 112 115
# ('Boston', (159, 164)) Boston 108 111
# ('amigo', (112, 116)) friend 84 87
# ('faculdade', (121, 129)) college 80 83
# ('seu', (166, 168)) his 112 115
# ('Tzarnaev', (154, 161)) Tzarnaev 92 95
# ('Boston', (125, 130)) Boston 76 79
# ('Cazaquistão', (47, 57)) Kazakhstan 28 31
# ('exterior', (367, 374)) overseas 248 251
# ('Dzokhar Tsarnaev', (86, 101)) Dzokhar Tsarnaev 44 47
# ('arma', (127, 130)) weapon 96 99
# ('amigo', (17, 21)) Friend 8 11
# ('Boston', (59, 64)) Boston 16 19
# ('amigo', (24, 28)) friend 20 23
# ('irmãos', (23, 28)) brothers 24 27
# ('chechena', (39, 46)) Chechen 20 23
# ('polícia', (2, 8)) Police 0 3
# ('pessoas', (91, 97)) others 84 87
# ('bombas', (143, 148)) bombs 100 103
# ('Dzhokhar Tsarnaev', (110, 126)) Dzhokhar Tsarnaev 80 83
# ('Tamerlan', (99, 106)) Tamerlan 72 75
# ('Estados Unidos', (64, 77)) United States 48 51
# ('rua', (168, 170)) street 124 127
# ('Boston', (175, 180)) Boston 120 123
# ('EUA', (59, 61)) U.S. 36 39
# ('prisão', (48, 53)) prison 52 55
# ('Dzhokhar', (63, 70)) Dzhokhar 52 55
# ('polícia', (53, 59)) police 44 47
# ('quintal', (124, 130)) backyard 92 95
# ('tiroteio', (38, 45)) gun 32 35
# ('Tamerlan', (13, 20)) Tamerlan 12 15
# ('amigo', (112, 116)) room 120 123
# ('dormitório', (170, 179)) dormitory 116 119
# ('Tazhayakov', (80, 89)) Tazhayakov 68 71
# ('Boston', (70, 75)) Boston 40 43
# ('pessoas', (91, 97)) people 60 63
# ('muçulmanos', (312, 321)) Muslims 224 227
# (None, (-1, -1)) American 232 235
# ('barco', (103, 107)) boat 164 167
# ('no', (144, 145)) U.S 200 203
# ('autoridades', (170, 180)) Authorities 120 123
# ('prisão', (111, 116)) jail 84 87
# ('Sua', (148, 150)) His 108 111
# ('bombas', (5, 10)) bombs 4 7
# ('Universidade de Massachusetts-Dartmouth', (184, 222)) University of Massachusetts-Dartmouth 132 135
# ('fogos de artifício', (243, 260)) fireworks 172 175
# ('amigos', (279, 284)) friends 180 183
# ('Tazhayakov', (0, 9)) Tazhayakov 0 3
# ('Azamat Tazhayakov', (0, 16)) Azamat Tazhayakov 0 3
# ('estudante', (22, 30)) student 20 23
# ('barco', (103, 107)) boat 76 79
# ('linha', (192, 196)) line 140 143
# ('Dzhokhar Tsarnaev', (0, 16)) Dzhokhar Tsarnaev 0 3
# ('ele', (192, 194)) he 128 131
# ('atentado', (38, 45)) Bombing 20 23
# ('condena', (9, 15)) Convicts 4 7
# ('condenou', (12, 19)) convicted 12 15
# ('atentado', (45, 52)) bombing 36 39
# ('atentado', (47, 54)) bombing 40 43
# ('explodiram', (12, 21)) exploded 8 11
# ('matando', (78, 84)) killing 52 55
# ('ferindo', (101, 107)) injuring 68 71
# ('detoná-las', (219, 228)) detonating 148 151
# ('morto', (26, 30)) killed 20 23
# ('atentados', (267, 275)) bombings 180 183
# ('proprietário', (2, 13)) owner 4 7
# ('oficina', (22, 28)) shop 20 23
# ('caminhão', (161, 168)) truck 28 31
# ('oficina', (22, 28)) agency 36 39
# ('Junction City', (57, 69)) Junction City 44 47
# ('Kansas', (72, 77)) Kan 56 59
# ('Timothy McVeigh', (92, 106)) Timothy McVeigh 72 75
# ('homem', (142, 146)) man 100 103
# ('que', (148, 150)) who 104 107
# ('caminhão Ryder', (161, 174)) Ryder truck 116 119
# ('Oklahoma City', (215, 227)) Oklahoma City 148 151
# ('federal', (204, 210)) federal 156 159
# ('prédio', (197, 202)) building 160 163
# ('Eu', (1, 2)) I 4 7
# ('ele', (36, 38)) him 24 27
# ('Eldon Elliott', (51, 63)) Eldon Elliott 40 43
# ('proprietário', (66, 77)) owner 52 55
# ("Elliott's Body Shop", (82, 100)) Elliott's Body Shop 60 63
# ('McVeigh', (139, 145)) McVeigh 104 107
# ('sua', (177, 179)) his 128 131
# ('loja', (181, 184)) shop 132 135
# ('caminhão', (229, 236)) truck 176 179
# ('caminhão Ryder', (328, 341)) Ryder truck 272 275
# ('Ele', (354, 356)) He 284 287
# ('McVeigh', (368, 374)) McVeigh 292 295
# ('Robert Kling', (389, 400)) Robert Kling 312 315
# ('Eu', (99, 100)) I 24 27
# ('todo mundo', (18, 27)) everybody 36 39
# ('ele', (37, 39)) he 48 51
# ('jurados', (45, 51)) jurors 56 59
# ('na', (121, 122)) U.S 64 67
# ('juiz', (58, 61)) Judge 84 87
# ('Richard Matsch', (82, 95)) Richard Matsch 88 91
# ('Eu', (99, 100)) I 104 107
# ('eles', (112, 115)) them 116 119
# ('sua', (25, 27)) your 24 27
# ('Departamento de Justiça', (61, 83)) Justice Department 44 47
# ('promotor', (49, 56)) prosecutor 52 55
# ('Scott Mendeloff', (86, 100)) Scott Mendeloff 56 59
# ('Elliott', (17, 23)) Elliott 16 19
# ('Quem', (1, 4)) Who 4 7
# ('Mendeloff', (12, 20)) Mendeloff 24 27
# ('Timothy McVeigh', (1, 15)) Timothy McVeigh 4 7
# ('Elliott', (25, 31)) Elliott 20 23
# ('Elliott', (24, 30)) him 12 15
# ('Elliott', (24, 30)) Elliott 24 27
# ('McVeigh', (0, 6)) McVeigh 0 3
# ('Ele', (113, 115)) He 68 71
# ('Elliott', (151, 157)) Elliott 84 87
# ('promotores', (39, 48)) prosecutors 28 31
# ('testemunhas', (76, 86)) witnesses 48 51
# ('chinesa', (177, 183)) Chinese 100 103
# ("McDonald's", (245, 254)) McDonald's 148 151
# ('restaurante', (233, 243)) restaurant 160 163
# ('McVeigh', (288, 294)) McVeigh 176 179
# ('promotores', (333, 342)) prosecutors 220 223
# ('ele', (123, 125)) he 228 231
# ('Junction City', (367, 379)) Junction City 240 243
# ('caminhão Ryder', (408, 421)) Ryder truck 276 279
# ('Elliott', (439, 445)) Elliott 296 299
# ('loja', (431, 434)) shop 308 311
# ('Murrah Federal Building', (2, 24)) Murrah Federal Building 4 7
# ('Oklahoma City', (29, 41)) Oklahoma City 20 23
# ('pessoas', (122, 128)) people 112 115
# ('outras', (152, 157)) others 136 139
# ('McVeigh', (0, 6)) McVeigh 0 3
# ('promotores', (3, 12)) Prosecutors 0 3
# ('McVeigh', (26, 32)) McVeigh 8 11
# ('Junction City', (43, 55)) Junction City 20 23
# ('onde', (73, 76)) where 44 47
# ('Ele', (138, 140)) he 48 51
# ('seu', (85, 87)) his 56 59
# ('Mercury Marquis', (108, 122)) Mercury Marquis 84 87
# ('Ele', (138, 140)) He 96 99
# ('J e K', (188, 192)) J and K 116 119
# ('estação', (170, 176)) depot 132 135
# ('onde', (195, 198)) where 136 139
# ('Ele', (138, 140)) he 140 143
# ('Elliott', (213, 219)) Elliott's 148 151
# ('Ryder', (285, 289)) Ryder 188 191
# ('caminhão', (276, 283)) truck 192 195
# ('McVeigh', (20, 26)) McVeigh 16 19
# ('Dreamland Motel', (43, 57)) Dreamland Motel 32 35
# ('promotores', (3, 12)) Prosecutors 0 3
# ('ele', (24, 26)) he 8 11
# ('caminhão', (38, 45)) truck 20 23
# ('Geary Lake', (51, 60)) Geary Lake 28 31
# ('Kansas', (66, 71)) Kansas 40 43
# ('caminhão', (158, 165)) truck 108 111
# ('no', (135, 136)) there 112 115
# ('que', (169, 171)) it 128 131
# ('Oklahoma City', (193, 205)) Oklahoma City 144 147
# ('Elliott', (0, 6)) Elliott 0 3
# ('McVeigh', (44, 50)) McVeigh 28 31
# ('oficina', (58, 64)) shop 48 51
# ('caminhão', (79, 86)) truck 64 67
# ('Elliott', (0, 6)) Elliott 0 3
# ('McVeigh', (18, 24)) McVeigh 12 15
# ('ele', (32, 34)) him 20 23
# ('Ele', (126, 128)) He 96 99
# ('caminhão', (139, 146)) truck 108 111
# ('motorista', (171, 179)) driver 120 123
# ('Robert Kling', (193, 204)) Robert Kling 156 159
# ('endereço', (223, 230)) address 180 183
# ('Redfield', (235, 242)) Redfield 188 191
# (None, (-1, -1)) S.D 196 199
# ('Elliott', (257, 263)) Elliott 216 219
# ('McVeigh', (39, 45)) McVeigh 12 15
# ('promotores', (51, 60)) prosecutors 32 35
# ('Yuhua Bai', (75, 83)) Yuhua Bai 40 43
# ('proprietário', (86, 97)) owner 52 55
# ('Hunam Palace', (102, 113)) Hunam Palace 60 63
# ('Junction City', (119, 131)) Junction City 76 79
# ('que', (134, 136)) who 88 91
# ('ela', (192, 194)) she 140 143
# ('interlocutor', (270, 281)) caller 200 203
# ('que', (150, 152)) who 204 207
# ('Kling', (302, 306)) Kling 224 227
# ('Sala 25', (420, 426)) Room 25 248 251
# ('Dreamland', (345, 353)) Dreamland 264 267
# ('McVeigh', (391, 397)) McVeigh 292 295
# ('Sala 25', (420, 426)) Room 25 304 307
# ('júri', (54, 57)) jury 28 31
# ('sala', (103, 106)) room 64 67
# ('Palácio Hunam', (115, 127)) Hunam Palace 76 79
# ('promotores', (3, 12)) Prosecutors 0 3
# ("David D'Albini", (34, 47)) David D'Albini 12 15
# ('gerente', (50, 56)) manager 32 35
# ("McDonald's", (61, 70)) McDonald's 44 47
# ('que', (82, 84)) who 72 75
# ('restaurante', (130, 140)) restaurant 100 103
# ('jurados', (34, 40)) jurors 20 23
# ('McVeigh', (48, 54)) McVeigh 28 31
# ('balcão', (108, 113)) counter 76 79
# ('restaurante', (132, 142)) restaurant 104 107
# ('saindo', (44, 49)) him 48 51
# ('restaurante', (54, 64)) restaurant 60 63
# ('carro', (89, 93)) car 60 63
# ('nitrato de amônio misturado com nitrometano', (94, 136)) ammonium nitrate laced with nitromethane 72 75
# ('documentos', (90, 99)) documents 56 59
# ('US$ 280,32', (267, 276)) $280.32 192 195
# ('US$ 280,32', (36, 45)) $280.32 28 31
# ('disse', (31, 35)) told 52 55
# ('perguntou', (37, 45)) asked 40 43
# ('disse', (19, 23)) said 24 27
# ('perguntou', (22, 30)) asked 28 31
# ('explosão', (65, 72)) explosion 44 47
# ('matando', (110, 116)) killing 104 107
# ('ferindo', (132, 138)) injuring 120 123
# ('chegou', (34, 39)) arrived 12 15
# ('vendeu', (78, 83)) sold 52 55
# ('comprou', (97, 103)) purchased 68 71
# ('detonado', (209, 216)) detonated 156 159
# ('tribunal', (111, 118)) court 84 87
# ('atentado', (185, 192)) bombing 136 139
# ('declarou', (42, 49)) declared 36 39
# ('disse', (358, 362)) said 288 291
# ('apresentaram', (50, 61)) presented 32 35
# ('dirigiu', (28, 34)) drove 12 15
# ('testemunhou', (8, 18)) testified 4 7
# ('disse', (251, 255)) said 220 223
# ('ligaram', (21, 27)) called 8 11
# ('reservar', (217, 224)) reserve 168 171
# ('Solicitado', (0, 9)) Asked 0 3
# ('movimentos', (274, 283)) movements 188 191
# ('chegou', (358, 363)) arrived 232 235
# ('alugou', (152, 157)) rented 108 111
# ('respondeu', (7, 15)) replied 20 23
# ('saiu', (423, 426)) driven 288 291
# ('caminhou', (155, 162)) walked 104 107
# ('ligou', (200, 204)) called 144 147
# ('foi', (52, 54)) came 32 35
# ('reservou', (68, 75)) reserved 56 59
# ('disse', (8, 12)) said 4 7
# ('alugou', (130, 135)) rented 100 103
# ('solicitou', (311, 319)) requested 236 239
# ('ligaram', (62, 68)) called 36 39
# ('ligação', (77, 83)) call 44 47
# ('saindo', (44, 49)) leaving 52 55
# ('aproximar', (92, 100)) approach 68 71
# ('sair', (124, 127)) walk 88 91

# %% [markdown]
# ### Convert sentence level annotations spans to document level

# %%
file_train = open("../../Datasets/WikiEvents/dev_pt_sent.json")
x = json.load(file_train)

# %%
import json
file_dev = open("../../Datasets/WikiEvents/dev_pt_sent.json")
file_train = open("../../Datasets/WikiEvents/train_pt_sent.json")
file_test = open("../../Datasets/WikiEvents/test_pt_sent.json")
docs_dev_pt = json.load(file_dev)
docs_train_pt = json.load(file_train)
docs_test_pt = json.load(file_test)
    
file_train.close()
file_dev.close()
file_test.close()

# %%
def sentence_to_doc_offset(annotation, sentences):
    sent_idx = annotation["sent_idx"]
    token_idx = annotation["start"]
    offset = 0
    for i in range(sent_idx):
        offset += len(sentences[i]) + 1
    annotation["start"] = offset + token_idx
    annotation["end"] = offset + annotation["end"]
    return annotation
    


for doc in docs_dev_pt:
    for ann in doc["entity_mentions"]:
        ann = sentence_to_doc_offset(ann, doc["sentences"])
    for ann in doc["event_mentions"]:
        ann["trigger"] = sentence_to_doc_offset(ann["trigger"], doc["sentences"])

for doc in docs_train_pt:
    for ann in doc["entity_mentions"]:
        ann = sentence_to_doc_offset(ann, doc["sentences"])
    for ann in doc["event_mentions"]:
        ann["trigger"] = sentence_to_doc_offset(ann["trigger"], doc["sentences"])

for doc in docs_test_pt:
    for ann in doc["entity_mentions"]:
        ann = sentence_to_doc_offset(ann, doc["sentences"])
    for ann in doc["event_mentions"]:
        ann["trigger"] = sentence_to_doc_offset(ann["trigger"], doc["sentences"])

# %%
saveJsonLines(docs_test_pt, "../../Datasets/WikiEvents/test_pt.jsonl")
f_out = open("../../Datasets/WikiEvents/test_pt.json", "w")
json.dump(docs_test_pt, f_out, indent=4, ensure_ascii=False)
f_out.flush()
f_out.close()

saveJsonLines(docs_train_pt, "../../Datasets/WikiEvents/train_pt.jsonl")
f_out = open("../../Datasets/WikiEvents/train_pt.json", "w")
json.dump(docs_train_pt, f_out, indent=4, ensure_ascii=False)
f_out.flush()
f_out.close()

saveJsonLines(docs_dev_pt, "../../Datasets/WikiEvents/dev_pt.jsonl")
f_out = open("../../Datasets/WikiEvents/dev_pt.json", "w")
json.dump(docs_dev_pt, f_out, indent=4, ensure_ascii=False)
f_out.flush()
f_out.close()

# %%
for i, doc in enumerate(docs_train):
    for ann in doc["entity_mentions"]:
        if ann["id"] == "2_VOA_EN_NW_2015.01.04.2583337-T346":
            print(i)
# Out:
# 51

# %%
file_dev = open("../../Datasets/WikiEvents/dev_pt.json")
file_train = open("../../Datasets/WikiEvents/train_pt.json")
file_test = open("../../Datasets/WikiEvents/test_pt.json")
docs_dev_pt = json.load(file_dev)
docs_train_pt = json.load(file_train)
docs_test_pt = json.load(file_test)
